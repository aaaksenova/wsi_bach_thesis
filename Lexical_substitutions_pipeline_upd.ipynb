# %% [markdown]
# # An Interpretable Approach to Lexical Semantic Change Detection with Lexical Substitution

# %% [markdown]
# Collecting data.

# %% [markdown]
# **Word sense induction (WSI)** is the problem of grouping occurrences of an ambiguous word according to the expressed sense of this word. Recently a new approach to this task was proposed, which generates possible substitutes for the ambiguous word in a particular context using neural language models, and then clusters sparse bag-of-words vectors built from these substitutes. Here we provide solution for the second part: clusterization of word usages using substitutes that were pregenerated based on the contexts.
#
# Algotithm:
#
#
# 1.   Prepared substitutes for target words in certain contexts and their probabilities from `russe_bts-rnc` are used. Substitutes are words that could be used in the same context as the target word. Probabilities are probabilities of the particular substitution.
# 2.   Substitutions are lemmatized and vectorized.
# 3.   BoW vectors are clustered using agglomerative clustering.
# 4. MaxARI is calculated.

# %% [markdown]
# Here all necessary modules are imported.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from collections import Counter
import os
from datetime import datetime
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
from pymorphy2 import MorphAnalyzer
from pathlib import Path
from time import time
import regex as re
from sklearn.feature_extraction import DictVectorizer
from sklearn.naive_bayes import BernoulliNB
from joblib import Memory
from sklearn.metrics import adjusted_rand_score as ARI
from sklearn.cluster import AgglomerativeClustering
# import sklearn.cluster.hierarchical
from scipy.spatial.distance import cdist
import seaborn as sns
from sklearn.metrics import silhouette_score
from tqdm.notebook import tqdm
from IPython.display import display

# %% [markdown]
# ## Predicting substitutes

# %%
import torch

# %%
def mask_before_target(idxs, line):

    start_id = int(idxs.split(',')[0].split('-')[0].strip())
    end_id = int(idxs.split(',')[0].split('-')[1].strip())
    return line[:start_id] + '[MASK] а также ' + line[start_id:]

def mask_after_target(idxs, line):

    start_id = int(idxs.split(',')[0].split('-')[0].strip())
    end_id = int(idxs.split(',')[0].split('-')[1].strip())
    return line[:end_id+1] + ' а также [MASK]' + line[end_id+1:]

# %%
df = pd.read_csv('./russe-wsi-kit/data/main/bts-rnc/train.csv', sep='\t')

# %%
df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id positions  \
# 0              1  балка              1               NaN     90-94
# 1              2  балка              1               NaN     69-73
# 2              3  балка              1               NaN   115-121
# 3              4  балка              1               NaN     85-90
# 4              5  балка              1               NaN     66-70
# ...          ...    ...            ...               ...       ...
# 3486        3487  штамп              4               NaN     81-86
# 3487        3488  штамп              4               NaN     85-90
# 3488        3489  штамп              4               NaN     71-77
# 3489        3490  штамп              4               NaN   107-112
# 3490        3491  штамп              4               NaN    95-100
#
#                                                 context
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
# [3491 rows x 6 columns]

# %%
df['masked_before_target'] = df[['positions', 'context']].apply(lambda x: mask_before_target(*x), axis=1)
df['masked_after_target'] = df[['positions', 'context']].apply(lambda x: mask_after_target(*x), axis=1)

# %%
sent = df.iloc[2]['masked_after_target']

# %%
sent
# Out:
# 'равнозначно обеспечивает и меланхоличную езду. Цельнометаллическое тело, усиленное передними и задними поперечными балками а также [MASK], наряду с работой подвески превращает машину в глыбу, всей плоскостью вросшую в'

# %%
from transformers import BertTokenizer, BertForMaskedLM

tokenizer = BertTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")
model = BertForMaskedLM.from_pretrained("DeepPavlov/rubert-base-cased")
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def predict_masked_sent(text, model, tokenizer, top_k=5):
    # Tokenize input
    text = "[CLS] %s [SEP]"%text
    tokenized_text = tokenizer.tokenize(text)
    masked_index = tokenized_text.index("[MASK]")
    indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
    tokens_tensor = torch.tensor([indexed_tokens])
    # tokens_tensor = tokens_tensor.to('cuda')    # if you have gpu

    # Predict all tokens
    with torch.no_grad():
        outputs = model(tokens_tensor)
        predictions = outputs[0]

    probs = torch.nn.functional.softmax(predictions[0, masked_index], dim=-1)
    top_k_weights, top_k_indices = torch.topk(probs, top_k, sorted=True)

    out = []
    for i, pred_idx in enumerate(top_k_indices):
        predicted_token = tokenizer.convert_ids_to_tokens([pred_idx])[0]
        token_weight = top_k_weights[i]
        out.append((token_weight, predicted_token))

    return out

# %%
sent = df.iloc[0]['masked_after_target']
sent
# Out:
# 'маленькой комнаты. Он был очень высок, наклонил голову, словно подпирая плечом потолочную балку а также [MASK], посмотрел на Сьянову серьезными черными глазами. -- Я из Москвы. Буду испытывать здесь'

# %%
df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id positions  \
# 0              1  балка              1               NaN     90-94
# 1              2  балка              1               NaN     69-73
# 2              3  балка              1               NaN   115-121
# 3              4  балка              1               NaN     85-90
# 4              5  балка              1               NaN     66-70
# ...          ...    ...            ...               ...       ...
# 3486        3487  штамп              4               NaN     81-86
# 3487        3488  штамп              4               NaN     85-90
# 3488        3489  штамп              4               NaN     71-77
# 3489        3490  штамп              4               NaN   107-112
# 3490        3491  штамп              4               NaN    95-100
#
#                                                 context  \
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
#                                    masked_before_target  \
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
#                                     masked_after_target
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
# [3491 rows x 8 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
df['masked_before_target'].iloc[1]
# Out:
# 'Пантюхин в Склифе сейчас. Он выползти на улицу успел, а на Золоткова [MASK] а также балка обрушилась. Эх, душой компании парень был! 28-летний Геннадий так и не'

# %%
df['before_subst_prob'] = df['masked_before_target'].progress_apply(lambda x:
                                          predict_masked_sent(x, model, tokenizer, top_k=150))
# Out:
#   0%|          | 0/3491 [00:00<?, ?it/s]

# %%
df['after_subst_prob'] = df['masked_after_target'].progress_apply(lambda x:
                                          predict_masked_sent(x, model, tokenizer, top_k=150))
# Out:
#   0%|          | 0/3491 [00:00<?, ?it/s]

# %%
import stanza
import pymorphy2

# %%
nlp = stanza.Pipeline('ru', processors='tokenize,pos,lemma,depparse')
morph = pymorphy2.MorphAnalyzer()
# Out:
# 2022-02-23 10:44:18 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | pos       | syntagrus |
# | lemma     | syntagrus |
# | depparse  | syntagrus |
# =========================
#
# 2022-02-23 10:44:18 INFO: Use device: cpu
# 2022-02-23 10:44:18 INFO: Loading: tokenize
# 2022-02-23 10:44:18 INFO: Loading: pos
# 2022-02-23 10:44:18 INFO: Loading: lemma
# 2022-02-23 10:44:19 INFO: Loading: depparse
# 2022-02-23 10:44:19 INFO: Done loading processors!

# %%
morph.parse('балкой')[0].tag
# Out:
# OpencorporaTag('NOUN,inan,femn sing,ablt')

# %%
def extract_ling_feats(idx, text):
    start_id = int(idx.split('-')[0].strip())
    end_id = int(idx.split('-')[1].strip())
    processed = nlp(text)
    case = morph.parse(text[start_id:end_id+1])[0].tag.case
    number = morph.parse(text[start_id:end_id+1])[0].tag.number
    dep=''
    for token in processed.iter_tokens():
        if start_id == token.start_char:
            dep = token.words[0].deprel
            break
    return case, number, dep

# %%
df[['case', 'number', 'dep']] = df[['positions', 'context']].progress_apply(lambda x:
                                          extract_ling_feats(*x), axis=1, result_type='expand')
# Out:
#   0%|          | 0/3491 [00:00<?, ?it/s]

# %%
for i in ['case', 'number', 'dep']:
    df[i + '_enc'], _ = pd.factorize(df[i.strip()])

# %%
from sklearn import preprocessing

x = df[['case_enc', 'number_enc', 'dep_enc']].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df[['case_enc', 'number_enc', 'dep_enc']] = pd.DataFrame(x_scaled)

# %%
df.head(5)
# Out:
#    context_id   word  gold_sense_id  predict_sense_id positions  \
# 0           1  балка              1               NaN     90-94
# 1           2  балка              1               NaN     69-73
# 2           3  балка              1               NaN   115-121
# 3           4  балка              1               NaN     85-90
# 4           5  балка              1               NaN     66-70
#
#                                              context  \
# 0  маленькой комнаты. Он был очень высок, наклони...
# 1  Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2  равнозначно обеспечивает и меланхоличную езду....
# 3  верхняя часть закрыта, замкнута, многократно о...
# 4  по телевизору: наши гол забили, я вскочил от р...
#
#                                 masked_before_target  \
# 0  маленькой комнаты. Он был очень высок, наклони...
# 1  Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2  равнозначно обеспечивает и меланхоличную езду....
# 3  верхняя часть закрыта, замкнута, многократно о...
# 4  по телевизору: наши гол забили, я вскочил от р...
#
#                                  masked_after_target  \
# 0  маленькой комнаты. Он был очень высок, наклони...
# 1  Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2  равнозначно обеспечивает и меланхоличную езду....
# 3  верхняя часть закрыта, замкнута, многократно о...
# 4  по телевизору: наши гол забили, я вскочил от р...
#
#                                    before_subst_prob  \
# 0  [(tensor(0.9854), ,), (tensor(0.0026), плиту),...
# 1  [(tensor(0.9077), ,), (tensor(0.0180), –), (te...
# 2  [(tensor(0.7706), ,), (tensor(0.0491), связями...
# 3  [(tensor(0.9830), ,), (tensor(0.0011), (), (te...
# 4  [(tensor(0.7925), ,), (tensor(0.0098), него), ...
#
#                                     after_subst_prob  case number    dep  \
# 0  [(tensor(0.1272), пол), (tensor(0.0548), ноги)...  accs   sing    obj
# 1  [(tensor(0.2998), балка), (tensor(0.0359), тож...  nomn   sing  nsubj
# 2  [(tensor(0.0542), балками), (tensor(0.0386), у...  ablt   plur    obl
# 3  [(tensor(0.0831), балками), (tensor(0.0274), б...  ablt   sing  advcl
# 4  [(tensor(0.0372), упал), (tensor(0.0318), уеха...  accs   sing    obl
#
#    case_enc  number_enc   dep_enc
# 0  0.142857         0.5  0.000000
# 1  0.285714         0.5  0.047619
# 2  0.428571         1.0  0.095238
# 3  0.428571         0.5  0.142857
# 4  0.142857         0.5  0.095238

# %%
df.to_csv('bts_rnc_substs.csv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/c2/mq2yd_150sdd11x87yqcqq0c0000gq/T/ipykernel_35783/2672124683.py in <module>
# ----> 1 df.to_csv('bts_rnc_substs.csv', sep='\t')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3561         )
#    3562
# -> 3563         return DataFrameRenderer(formatter).to_csv(
#    3564             path_or_buf,
#    3565             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315         libwriters.write_csv_rows(
#     316             data,
#     317             ix,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor.py in __repr__(self)
#     247             return handle_torch_function(Tensor.__repr__, (self,), self)
#     248         # All strings are unicode in Python 3.
# --> 249         return torch._tensor_str._str(self)
#     250
#     251     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor_str.py in _str(self)
#     413 def _str(self):
#     414     with torch.no_grad():
# --> 415         return _str_intern(self)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor_str.py in _str_intern(inp)
#     409         suffixes.append('tangent={}'.format(tangent))
#     410
# --> 411     return _add_suffixes(prefix + tensor_str, suffixes, indent, force_newline=self.is_sparse)
#     412
#     413 def _str(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/_tensor_str.py in _add_suffixes(tensor_str, suffixes, indent, force_newline)
#     254 def _add_suffixes(tensor_str, suffixes, indent, force_newline):
#     255     tensor_strs = [tensor_str]
# --> 256     last_line_len = len(tensor_str) - tensor_str.rfind('\n') + 1
#     257     for suffix in suffixes:
#     258         suffix_len = len(suffix)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Data collection

# %% [markdown]
# `substitutes_dump` – lists of substitutions with their probablities
# `data_name` – dataset with target words and examples (contexts of word usages)

# %%
substitutes_dump = '/content/xlm/russe_bts-rnc/train_1-limitNone-maxexperwordNone/modelNone-beamsearchFalse/<mask><mask>-(а-также-T)-2ltr2f_topk150_fixspacesTrue.npz&/content/xlm/russe_bts-rnc/train_1-limitNone-maxexperwordNone/modelNone-beamsearchFalse/T-(а-также-<mask><mask>)-2ltr2f_topk150_fixspacesTrue.npz&'
data_name = '/content/summer-wsi/russe-wsi-kit/data/main/bts-rnc/train.csv'

# %% [markdown]
# Function `load_substs` collects substitutions, probabilities and examples to one main DataFrame.

# %%
def load_substs(substs_fname, limit=None, drop_duplicates=False, 
                data_name = None, show=True):
    '''
    If more than one set of substitutes is used, this function combines them.
    '''
    if substs_fname.endswith('&'):
        split = substs_fname.strip('&').split('&')
        if show:
            print(f'Combining:', split)
        dfinps = [load_substs_(p, limit, drop_duplicates, data_name) \
                  for p in split]
        res = dfinps[0]
        nm = len(split[0].split('<mask>'))-1
        for dfinp in dfinps[1:]:
            res = res.merge(dfinp, on=['context','positions'], \
                            how='inner', suffixes=('','_y'))
            res.substs_probs = intersect_sparse(res.substs_probs, \
                                                res.substs_probs_y, \
                                                nmasks=nm, s=0.0)        
            res.drop(columns=[c for c in res.columns if c.endswith('_y')], \
                     inplace=True)
        if show:
            print('\nExamples for one meaning:')
            ex = res.loc[(res['word'] == 'балка') & \
                          (res['gold_sense_id'] == 1)].head(2)
            print('\nExample #1\nword:', tuple(ex.word)[0],
              '\ngold_sense_id:', tuple(ex.gold_sense_id)[0],
              '\ncontext:', tuple(ex.context)[0], '\nsubstitutes & probabilities:',
              tuple(ex.substs_probs)[0])
            print('\nExample #2\nword:', tuple(ex.word)[1],
              '\ngold_sense_id:', tuple(ex.gold_sense_id)[1],
              '\ncontext:', tuple(ex.context)[1], '\nsubstitutes & probabilities:',
              tuple(ex.substs_probs)[1])


            print('\nExamples for differrent menings:')
            ex1 = res.loc[(res['word'] == 'балка') & \
                          (res['gold_sense_id'] == 1)].head(1)
            ex2 = res.loc[(res['word'] == 'балка') & \
                          (res['gold_sense_id'] == 2)].head(1)
            print('\nExample #1\nword:', tuple(ex1.word)[0],
              '\ngold_sense_id:', tuple(ex1.gold_sense_id)[0],
              '\ncontext:', tuple(ex1.context)[0], '\nsubstitutes & probabilities:',
              tuple(ex1.substs_probs)[0])
            print('\nExample #2\nword:', tuple(ex2.word)[0],
              '\ngold_sense_id:', tuple(ex2.gold_sense_id)[0],
              '\ncontext:', tuple(ex2.context)[0], '\nsubstitutes & probabilities:',
              tuple(ex2.substs_probs)[0])
        return res
    elif substs_fname.endswith('+'): 
        split = substs_fname.strip('+').split('+') # комментарий
        p1 = '+'.join(split[:-1])
        s = float(split[-1]) 
        p2 = re.sub(r'((<mask>)+)(.*?)T',r'T\3\1',p1)
        if p2==p1:
            p2 =  re.sub(r'T(.*?)((<mask>)+)',r'\2\1T',p1)
        print(f'Combining {p1} and {p2}')
        if p1==p2:
            raise Exception('Cannot conver fname to symmetric one:', p1)
        dfinp1, dfinp2 = (load_substs_(p, limit, drop_duplicates, data_name) \
                          for p in (p1,p2))
        dfinp = dfinp1.merge(dfinp2, on=['context','positions'], how='inner', \
                             suffixes=('','_y'))
        dfinp.substs_probs = intersect_sparse(dfinp.substs_probs, \
                                              dfinp.substs_probs_y, \
                                              nmasks=len(substs_fname.split('<mask>'))-1, \
                                              s=s)
        dfinp.drop(columns=[c for c in dfinp.columns if c.endswith('_y')], \
                   inplace=True)
        return dfinp
    else:
        return load_substs_(substs_fname, limit, drop_duplicates, data_name)

# %%
def load_substs_(substs_fname, limit=None, drop_duplicates=True, data_name = None):
    '''
    Collects substitutions, probabilities and examples to one main DataFrame.
    '''
    st = time()
    p = Path(substs_fname) 
    npz_filename_to_save = None
    # print(time()-st, 'Loading substs from ', p)

    # substitutions and probabilities
    if substs_fname.endswith('.npz'): 
        arr_dict = np.load(substs_fname, allow_pickle=True)
        # separate dictionaries for substitutions and probabilities
        ss,pp = arr_dict['substs'], arr_dict['probs'] 
        ss,pp = [list(s) for s in ss], [list(p) for p in pp]
        # creating a DataFrame
        substs_probs = pd.DataFrame({'substs':ss, 'probs':pp}) 
        substs_probs = substs_probs.apply(lambda r: [(p,s) for s,p in zip(r.substs, r.probs)], axis=1) 

    # examword usages and contexts
    p_ex = p.parent / (p.name+'.input')
    if os.path.isfile(p_ex):
        # print(time()-st,'Loading examples from ', p_ex)
        dfinp = pd.read_csv(p_ex, nrows=limit)
        dfinp['positions'] = dfinp['positions'].apply(pd.eval).apply(tuple)
        dfinp['word_at'] = dfinp.apply(lambda r: r.context[slice(*r.positions)], 
                                       axis=1)  # word_at stores wordform as it occured in text

    dfinp.positions = dfinp.positions.apply(tuple)
    # adding substitutions and probabilities to main DF
    dfinp['substs_probs'] = substs_probs 
    if drop_duplicates: # deleting duplicates
        dfinp = dfinp.drop_duplicates('context')
    dfinp.reset_index(inplace = True)
    # display(dfinp)
    dfinp['positions'] = dfinp.positions.apply(tuple)
    return dfinp

# %% [markdown]
# Here we choose best substitutes for target word using substitutes for both templates by multiplication of probabilities.
#
# \begin{align}
# \mathcal{P}^{final} = P(s_i|Context, templ_1) \cdot P(s_i|Context, templ_2)
# \end{align}
#
# But we do not want to throw immediately the substitute if it is in only one set (generated for one template), so we use product of smoothed probability distributions as a final proba.
#
# ---
# Here we find smoothing rates.
#
# $\alpha_{1,2}$ is to represent the proba of any substitution not inclided in the substitutes candidate set. This evenly (across all the possible $250000$ tokens) distributes the remainder calcilated as $1 - \text{sum of all the known substitutes probas}$.
#
# \begin{align}
# \alpha_1 = \frac{1 - \sum_{i=1}^{n_{substs\_probs_1}}P_{1i}}{ 250000^{n_{masks}}}
# \end{align}
#
# \begin{align}
# \alpha_2 = \frac{1 - \sum_{i=1}^{n_{substs\_probs_2}}P_{2i}}{ 250000^{n_{masks}}}
# \end{align}
#
# ---
#
# Then we find a smoothed probability for each substitute provided by context.
#
# \begin{align}
# P(s_i|Context, templ_1) =
#     \left\{
# \begin{array}{cl}
# P_{1i} + \alpha_1 & s_i \in substs\_probs_1 \\
# \alpha_1 & s_i \notin substs\_probs_1
# \end{array}
# \right.
# \end{align}
#
# \begin{align}
# P(s_i|Context, templ_2) =
#     \left\{
# \begin{array}{cl}
# P_{2i} + \alpha_2 & s_i \in substs\_probs_2 \\
# \alpha_2 & s_i \notin substs\_probs_2
# \end{array}
# \right.
# \end{align}
#
# Product of smoothed probability distributions:
#
# \begin{align}
# \mathcal{P}^{final}_{i} =
#     \left\{
# \begin{array}{cl}
# (P_{1i} + \alpha_1) \cdot (P2i + alpha2) & s_i \in substs\_probs_1 \land s_i \in substs\_probs_2 \\
# (P_{1i} + \alpha_1) \cdot alpha2 & s_i \in substs\_probs_1 \land s_i \notin substs\_probs_2 \\
# \alpha_1 \cdot (P_{2i} + \alpha_2) & s_i \notin substs\_probs_1 \land s_i \in substs\_probs_2 \\
# \alpha_1 \cdot \alpha_2 & s_i \notin substs\_probs_1 \land s_i \notin substs\_probs_2
# \end{array}
# \right.
# \end{align}
#
# We get two matricies (for two templates) with a probability for the substitute if it is in the certain set or zero if it is not.
#
# \begin{align}
# f_{1i} =
#     \left\{
# \begin{array}{cl}
# P_{1i} & s_i \in substs\_probs_1 \\
# 0 & s_i \notin substs\_probs_1
# \end{array}
# \right.
# \end{align}
#
#
#
# \begin{align}
# f_{2i} =
#     \left\{
# \begin{array}{cl}
# P_{2i} & s_i \in substs\_probs_2 \\
# 0 & s_i \notin substs\_probs_2
# \end{array}
# \right.
# \end{align}
#
# Multiplication of the respective matricies ($\forall i f_{1i} \in F_1$) using product of smoothed probability distributions.
#
# \begin{align}
# \mathcal{P}^{final} = F_1 \cdot F_2 + \alpha_1 \cdot F_2 + \alpha_2 \cdot F_1 + \alpha_1 \cdot \alpha_2
# \end{align}

# %% [markdown]
# We do not use $\alpha_1 \cdot \alpha_2$ **in code**, because probabilities for the substitutes that are not in both sets are too low, and we need to save memory resources.
#
# Owing to the size of the final matrix we use the sparse matrix.
# Then we find substitutes with the highest probabilities.

# %%
def intersect_sparse(substs_probs, substs_probs_y, nmasks=1, s=0, debug=False):
    '''
    Combines different sets of substitutes (for different tamplates) using
    product of smoothed probability distributions.
    '''
    
    vec = DictVectorizer(sparse=True)
    f1=substs_probs.apply(lambda l: {s:p for p,s in l})
    f2=substs_probs_y.apply(lambda l: {s:p for p,s in l})
    vec.fit(list(f1)+list(f2))
    f1,f2 = (vec.transform(list(f)) for f in (f1,f2)) # sparse matrix

    alpha1, alpha2 = ((1. - f.sum(axis=-1).reshape(-1,1)) / 250000**nmasks \
                      for f in (f1, f2))
    prod = f1.multiply(f2) + f1.multiply(alpha2) + f2.multiply(alpha1)
    # + alpha1*alpha2 is ignored to preserve sparsity 
    # finally, we don't want substs with 0 
    # probs before smoothing in both distribs
    fn = np.array(vec.feature_names_)
    maxlen=(substs_probs_y.apply(len)+substs_probs.apply(len)).max()
    m = prod
    n_texts = m.shape[0]
    
    def reverse_argsort(mdata):
        return np.argsort(mdata)[::-1]
    
    idx = list()
    for text_ix in range(n_texts):
      # sparce matrices are used to preserve high performance
      # refer to https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html
      # to learn the sparse matrices indexing (i.e. what is `indptr` and `data`)
        text_sparse_indices = m.indices[m.indptr[text_ix]:m.indptr[text_ix+1]]
        text_sparse_data = m.data[m.indptr[text_ix]:m.indptr[text_ix+1]]
        text_sp_data_revsorted_ixes = reverse_argsort(text_sparse_data)
        smth = text_sparse_indices[text_sp_data_revsorted_ixes]
        idx.append(smth)

    l = list()
    for text_ix, text_sparse_ixes_sorted in enumerate(idx):
        probas = m[text_ix].toarray()[0,text_sparse_ixes_sorted]
        substs = fn[text_sparse_ixes_sorted]
        good_substs = list()
        for proba, subst in zip(probas, substs):
      
            if subst.startswith(' ') and ' ' not in subst.strip():
                good_substs.append((proba, subst))
            l.append(good_substs)
 
    print('Combination: ', l[0][:10])
    return l

# %% [markdown]
# ---

# %%
df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id positions  \
# 0              1  балка              1               NaN     90-94
# 1              2  балка              1               NaN     69-73
# 2              3  балка              1               NaN   115-121
# 3              4  балка              1               NaN     85-90
# 4              5  балка              1               NaN     66-70
# ...          ...    ...            ...               ...       ...
# 3486        3487  штамп              4               NaN     81-86
# 3487        3488  штамп              4               NaN     85-90
# 3488        3489  штамп              4               NaN     71-77
# 3489        3490  штамп              4               NaN   107-112
# 3490        3491  штамп              4               NaN    95-100
#
#                                                 context  \
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
#                                    masked_before_target  \
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
#                                     masked_after_target  \
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
#                                       before_subst_prob  \
# 0     [(tensor(0.9854), ,), (tensor(0.0026), плиту),...
# 1     [(tensor(0.9077), ,), (tensor(0.0180), –), (te...
# 2     [(tensor(0.7706), ,), (tensor(0.0491), связями...
# 3     [(tensor(0.9830), ,), (tensor(0.0011), (), (te...
# 4     [(tensor(0.7925), ,), (tensor(0.0098), него), ...
# ...                                                 ...
# 3486  [(tensor(0.9119), ,), (tensor(0.0089), партии)...
# 3487  [(tensor(0.5066), -), (tensor(0.3153), ,), (te...
# 3488  [(tensor(0.9507), ,), (tensor(0.0273), -), (te...
# 3489  [(tensor(0.8356), ,), (tensor(0.0189), :), (te...
# 3490  [(tensor(0.8519), ,), (tensor(0.0253), элемент...
#
#                                        after_subst_prob
# 0     [(tensor(0.1272), пол), (tensor(0.0548), ноги)...
# 1     [(tensor(0.2998), балка), (tensor(0.0359), тож...
# 2     [(tensor(0.0542), балками), (tensor(0.0386), у...
# 3     [(tensor(0.0831), балками), (tensor(0.0274), б...
# 4     [(tensor(0.0372), упал), (tensor(0.0318), уеха...
# ...                                                 ...
# 3486  [(tensor(0.6548), партии), (tensor(0.0712), па...
# 3487  [(tensor(0.0991), говорит), (tensor(0.0546), н...
# 3488  [(tensor(0.3694), клише), (tensor(0.0674), сло...
# 3489  [(tensor(0.0290), схема), (tensor(0.0248), схе...
# 3490  [(tensor(0.4185), те), (tensor(0.1433), элемен...
#
# [3491 rows x 10 columns]

# %% [markdown]
# As you can see below, combination of substitutes improves their quality and they fit context better.

# %% [markdown]
# Here we see that substitutes for one meaning are similar and for different meanings are more different.

# %%
df = load_substs(substitutes_dump, data_name=data_name)
# Out:
# Combining: ['/content/xlm/russe_bts-rnc/train_1-limitNone-maxexperwordNone/modelNone-beamsearchFalse/<mask><mask>-(а-также-T)-2ltr2f_topk150_fixspacesTrue.npz', '/content/xlm/russe_bts-rnc/train_1-limitNone-maxexperwordNone/modelNone-beamsearchFalse/T-(а-также-<mask><mask>)-2ltr2f_topk150_fixspacesTrue.npz']
# Combination:  [(0.0003074132201598033, ' решетку'), (4.1475361323760285e-05, ' поверхность'), (3.976416282017758e-05, ' опору'), (2.2270818190058624e-05, ' трубу'), (2.102492416240878e-05, ' мебель'), (9.649139098880059e-06, ' спинку'), (9.437091495716981e-06, ' балку'), (8.321624868184736e-06, ' доску'), (8.03497520660322e-06, ' раму'), (7.317509182332922e-06, ' панель')]
#
# Examples for one meaning:
#
# Example #1
# word: балка
# gold_sense_id: 1
# context: маленькой комнаты. Он был очень высок, наклонил голову, словно подпирая плечом потолочную балку, посмотрел на Сьянову серьезными черными глазами. -- Я из Москвы. Буду испытывать здесь
# substitutes & probabilities: [(0.0003074132201598033, ' решетку'), (4.1475361323760285e-05, ' поверхность'), (3.976416282017758e-05, ' опору'), (2.2270818190058624e-05, ' трубу'), (2.102492416240878e-05, ' мебель'), (9.649139098880059e-06, ' спинку'), (9.437091495716981e-06, ' балку'), (8.321624868184736e-06, ' доску'), (8.03497520660322e-06, ' раму'), (7.317509182332922e-06, ' панель'), (5.585483663846113e-06, ' коробку'), (5.49844362694596e-06, ' щель'), (5.211723216924868e-06, ' палку'), (3.8057957598132164e-06, ' плотину'), (3.767456401386647e-06, ' стул'), (3.3928134681336975e-06, ' кровать'), (1.6089072738170948e-06, ' ручку'), (1.5056553108295944e-06, ' дорожку'), (8.254706275536603e-07, ' сетку'), (6.208307872062609e-07, ' ширму'), (4.557973551397005e-07, ' кисть'), (2.951072363964518e-07, ' жену'), (2.518606899224717e-07, ' бегу'), (2.0063051541493482e-07, ' сидение'), (9.938894122853198e-08, ' корочку'), (8.03326537191543e-08, ' маску'), (1.8248128080128103e-12, ' плиту'), (8.41099312765252e-13, ' стенку'), (2.934104405592628e-13, ' планку'), (2.2066437163684637e-13, ' стены'), (2.2047689113735633e-13, ' ободу'), (1.0729192277594875e-13, ' плечо'), (1.0554165446262951e-13, ' нишу'), (1.0170868983730731e-13, ' педаль'), (9.808705446751057e-14, ' линию'), (9.712436172702634e-14, ' плату'), (9.028993360756167e-14, ' полку'), (8.86523350521059e-14, ' лампу'), (8.697176344977604e-14, ' крышу'), (8.232608122930752e-14, ' столовую'), (7.72328116115141e-14, ' кресло'), (6.726979662031334e-14, ' розу'), (5.856280848517056e-14, ' стонку'), (5.624704875115189e-14, ' вилку'), (5.586427186839064e-14, ' крышку'), (5.225361250711231e-14, ' колонну'), (4.880267108909595e-14, ' обои'), (4.6590119951977434e-14, ' полочку'), (4.322381831778121e-14, ' пробку'), (3.85181742664259e-14, ' подставку'), (3.839210996892096e-14, ' кровлю'), (3.804255331826452e-14, ' накладку'), (2.7025364222136006e-14, ' плоть'), (2.5564949824973562e-14, ' столик'), (2.542267065217244e-14, ' проставку'), (2.2932578499098363e-14, ' порог'), (2.2072724578507225e-14, ' дерево'), (2.0858669159996275e-14, ' петлю'), (1.8924383159572778e-14, ' стекло'), (1.5877378452117648e-14, ' настил'), (1.4758453370748532e-14, ' стекла'), (1.4482758774088176e-14, ' арку'), (1.3768236143012535e-14, ' табличку'), (1.3353856437055641e-14, ' полосу'), (1.3345575349097958e-14, ' шахту'), (1.3189684909453652e-14, ' подушки'), (1.300594002394505e-14, ' жижу'), (1.2947596877167795e-14, ' дугу'), (1.2858006708229723e-14, ' ковер'), (1.2684476293593837e-14, ' клетку'), (1.1933264036727887e-14, ' шею'), (1.1777397851603219e-14, ' угол'), (1.1663060309531537e-14, ' шторку'), (1.0830406042919157e-14, ' кровати'), (1.074675893866241e-14, ' ступеньки'), (1.0725839761861041e-14, ' крошку'), (1.0713973176559637e-14, ' камни'), (1.0651188589645574e-14, ' ногами'), (1.0607034970822112e-14, ' пластину'), (1.0467609072265127e-14, ' пленку'), (1.0390882324645953e-14, ' шторы'), (1.0274176326469309e-14, ' грелку'), (9.301514891060416e-15, ' резину'), (9.134577354794314e-15, ' колено'), (8.724793901041585e-15, ' грань'), (8.697113037628522e-15, ' чашу'), (8.093061483948024e-15, ' половую'), (8.072368079435316e-15, ' матрац'), (8.000385545796861e-15, ' горло'), (7.875265759021597e-15, ' здание'), (7.815953343782643e-15, ' проводку'), (7.759327481200059e-15, ' заставку'), (7.451475855911e-15, ' плитку'), (7.309665528430343e-15, ' диванчик'), (7.020076870866634e-15, ' свечу'), (6.936244980514048e-15, ' основу'), (6.894067362089746e-15, ' матку'), (6.836453019538678e-15, ' столбу'), (6.7722486202924085e-15, ' гладь'), (6.701017566674327e-15, ' разводку'), (6.651197593114372e-15, ' крыло'), (6.640535947355554e-15, ' пятку'), (6.637777677328022e-15, ' капель'), (6.62601031807305e-15, ' шкафы'), (6.537032050055114e-15, ' цедру'), (6.517469910610266e-15, ' кухню'), (6.178526706503619e-15, ' ведро'), (6.17727337496932e-15, ' стенами'), (6.085803500192241e-15, ' вышку'), (5.9472161796228514e-15, ' поясницу'), (5 ...
#
# Example #2
# word: балка
# gold_sense_id: 1
# context: Пантюхин в Склифе сейчас. Он выползти на улицу успел, а на Золоткова балка обрушилась. Эх, душой компании парень был! 28-летний Геннадий так и не
# substitutes & probabilities: [(0.020003307469640956, ' крыша'), (0.0001694636908407752, ' плита'), (7.157191885023099e-05, ' здание'), (7.113804858050237e-05, ' труба'), (2.7772886507730534e-05, ' стена'), (1.3841349338151593e-05, ' горка'), (1.1301936525435628e-05, ' стекло'), (5.553581211036631e-06, ' дорожка'), (5.3581456551647866e-06, ' кровать'), (4.0366101117087256e-06, ' коробка'), (3.893923839228803e-06, ' дамба'), (3.848943037469179e-06, ' лавка'), (2.4744016645045234e-06, ' панель'), (2.4561069141586353e-06, ' палатка'), (1.7955346926381483e-06, ' одежда'), (1.7286728577951439e-06, ' свеча'), (1.3793638407450904e-06, ' ограждения'), (1.264627112239044e-06, ' палка'), (1.0570522852213854e-06, ' батарея'), (8.553321027826766e-07, ' спина'), (8.127501112475047e-07, ' куча'), (7.909578807865345e-07, ' печь'), (7.595470891241159e-07, ' охрана'), (7.113906692960504e-07, ' куртка'), (7.057601327836274e-07, ' доска'), (6.029395781831292e-07, ' плеча'), (4.573289977613904e-07, ' поверхность'), (4.5581460912248413e-07, ' котельная'), (3.956920400752813e-07, ' ванна'), (3.638168430633302e-07, ' стрела'), (3.1474465439910924e-07, ' скала'), (2.9455485692813597e-07, ' трещина'), (2.694004586318427e-07, ' корова'), (2.6092868130253754e-07, ' карета'), (2.2309333069291274e-07, ' туча'), (1.9361540543975885e-07, ' блокировка'), (1.9027662680821975e-07, ' парус'), (1.6144611953520892e-07, ' матушка'), (1.3798262003175905e-07, ' ребра'), (1.1998819944058954e-07, ' плотина'), (5.6004277812938e-08, ' танка'), (4.922326593313768e-08, ' домовая'), (3.788300688397906e-13, ' деревня'), (1.4416249507158742e-13, ' веранда'), (1.1457104114772741e-13, ' столба'), (8.770416766786863e-14, ' колонна'), (8.265653319055049e-14, ' башня'), (5.621638267609565e-14, ' обочина'), (4.902611095581341e-14, ' комната'), (4.809600864539155e-14, ' рампа'), (4.684455512234316e-14, ' дерево'), (3.94901976338176e-14, ' беседка'), (3.783638931668091e-14, ' мебель'), (3.595180000090995e-14, ' свалка'), (2.862649944468374e-14, ' кровля'), (2.475822137091945e-14, ' заря'), (2.4270745544745903e-14, ' ферма'), (2.146734113430651e-14, ' строчка'), (2.0721391745708896e-14, ' леска'), (1.9859586811893692e-14, ' домика'), (1.9282118035537188e-14, ' подушка'), (1.7414498278947915e-14, ' столовая'), (1.602256139906676e-14, ' щель'), (1.5875886710276646e-14, ' ветра'), (1.5533873037960673e-14, ' стойка'), (1.4901338360447748e-14, ' шахта'), (1.3512497170384703e-14, ' купола'), (1.2795128399330306e-14, ' вагонка'), (1.2086969901745087e-14, ' возня'), (1.1936850720438045e-14, ' сетка'), (1.1736683929894748e-14, ' камня'), (1.122435179444858e-14, ' пила'), (1.094596729743049e-14, ' домик'), (1.0619255481906992e-14, ' тропа'), (1.051618344419598e-14, ' сумка'), (9.544387929633759e-15, ' трибуна'), (9.102851441801779e-15, ' бутылка'), (9.05700800275607e-15, ' решетка'), (8.741635286197941e-15, ' трава'), (8.50110014685498e-15, ' черепица'), (8.280502208382797e-15, ' тишина'), (7.837541390287974e-15, ' длина'), (7.754861089836318e-15, ' тоска'), (7.670783681149823e-15, ' капля'), (7.3339571097885e-15, ' дыра'), (7.05287679263944e-15, ' мусор'), (7.0060774172549985e-15, ' елка'), (6.9276048213269255e-15, ' водителя'), (6.828126421125811e-15, ' пирамида'), (6.718370333862496e-15, ' талона'), (6.717006724696755e-15, ' урна'), (6.660286889109059e-15, ' веревка'), (6.64069453159667e-15, ' драка'), (6.614288087419008e-15, ' погода'), (6.603108576065829e-15, ' железка'), (6.443181646870458e-15, ' лифты'), (6.338272161046126e-15, ' молния'), (6.143017910459755e-15, ' мастерская'), (6.105968596879015e-15, ' тележка'), (6.102553662364233e-15, ' опора'), (5.948501187053805e-15, ' собаку'), (5.897421778291056e-15, ' снега'), (5.870933216468978e-15, ' балконка'), (5.664264938075361e-15, ' грузовик'), (5.621461050965578e-15, ' весна'), (5.546637924329237e-15, ' крылья'), (5.525872442553836e-15, ' кривая'), (5.413025627168244e-15, ' забор'), (5.378337317945832e-15, ' полицейских'), (5.22013629154 ...
#
# Examples for differrent menings:
#
# Example #1
# word: балка
# gold_sense_id: 1
# context: маленькой комнаты. Он был очень высок, наклонил голову, словно подпирая плечом потолочную балку, посмотрел на Сьянову серьезными черными глазами. -- Я из Москвы. Буду испытывать здесь
# substitutes & probabilities: [(0.0003074132201598033, ' решетку'), (4.1475361323760285e-05, ' поверхность'), (3.976416282017758e-05, ' опору'), (2.2270818190058624e-05, ' трубу'), (2.102492416240878e-05, ' мебель'), (9.649139098880059e-06, ' спинку'), (9.437091495716981e-06, ' балку'), (8.321624868184736e-06, ' доску'), (8.03497520660322e-06, ' раму'), (7.317509182332922e-06, ' панель'), (5.585483663846113e-06, ' коробку'), (5.49844362694596e-06, ' щель'), (5.211723216924868e-06, ' палку'), (3.8057957598132164e-06, ' плотину'), (3.767456401386647e-06, ' стул'), (3.3928134681336975e-06, ' кровать'), (1.6089072738170948e-06, ' ручку'), (1.5056553108295944e-06, ' дорожку'), (8.254706275536603e-07, ' сетку'), (6.208307872062609e-07, ' ширму'), (4.557973551397005e-07, ' кисть'), (2.951072363964518e-07, ' жену'), (2.518606899224717e-07, ' бегу'), (2.0063051541493482e-07, ' сидение'), (9.938894122853198e-08, ' корочку'), (8.03326537191543e-08, ' маску'), (1.8248128080128103e-12, ' плиту'), (8.41099312765252e-13, ' стенку'), (2.934104405592628e-13, ' планку'), (2.2066437163684637e-13, ' стены'), (2.2047689113735633e-13, ' ободу'), (1.0729192277594875e-13, ' плечо'), (1.0554165446262951e-13, ' нишу'), (1.0170868983730731e-13, ' педаль'), (9.808705446751057e-14, ' линию'), (9.712436172702634e-14, ' плату'), (9.028993360756167e-14, ' полку'), (8.86523350521059e-14, ' лампу'), (8.697176344977604e-14, ' крышу'), (8.232608122930752e-14, ' столовую'), (7.72328116115141e-14, ' кресло'), (6.726979662031334e-14, ' розу'), (5.856280848517056e-14, ' стонку'), (5.624704875115189e-14, ' вилку'), (5.586427186839064e-14, ' крышку'), (5.225361250711231e-14, ' колонну'), (4.880267108909595e-14, ' обои'), (4.6590119951977434e-14, ' полочку'), (4.322381831778121e-14, ' пробку'), (3.85181742664259e-14, ' подставку'), (3.839210996892096e-14, ' кровлю'), (3.804255331826452e-14, ' накладку'), (2.7025364222136006e-14, ' плоть'), (2.5564949824973562e-14, ' столик'), (2.542267065217244e-14, ' проставку'), (2.2932578499098363e-14, ' порог'), (2.2072724578507225e-14, ' дерево'), (2.0858669159996275e-14, ' петлю'), (1.8924383159572778e-14, ' стекло'), (1.5877378452117648e-14, ' настил'), (1.4758453370748532e-14, ' стекла'), (1.4482758774088176e-14, ' арку'), (1.3768236143012535e-14, ' табличку'), (1.3353856437055641e-14, ' полосу'), (1.3345575349097958e-14, ' шахту'), (1.3189684909453652e-14, ' подушки'), (1.300594002394505e-14, ' жижу'), (1.2947596877167795e-14, ' дугу'), (1.2858006708229723e-14, ' ковер'), (1.2684476293593837e-14, ' клетку'), (1.1933264036727887e-14, ' шею'), (1.1777397851603219e-14, ' угол'), (1.1663060309531537e-14, ' шторку'), (1.0830406042919157e-14, ' кровати'), (1.074675893866241e-14, ' ступеньки'), (1.0725839761861041e-14, ' крошку'), (1.0713973176559637e-14, ' камни'), (1.0651188589645574e-14, ' ногами'), (1.0607034970822112e-14, ' пластину'), (1.0467609072265127e-14, ' пленку'), (1.0390882324645953e-14, ' шторы'), (1.0274176326469309e-14, ' грелку'), (9.301514891060416e-15, ' резину'), (9.134577354794314e-15, ' колено'), (8.724793901041585e-15, ' грань'), (8.697113037628522e-15, ' чашу'), (8.093061483948024e-15, ' половую'), (8.072368079435316e-15, ' матрац'), (8.000385545796861e-15, ' горло'), (7.875265759021597e-15, ' здание'), (7.815953343782643e-15, ' проводку'), (7.759327481200059e-15, ' заставку'), (7.451475855911e-15, ' плитку'), (7.309665528430343e-15, ' диванчик'), (7.020076870866634e-15, ' свечу'), (6.936244980514048e-15, ' основу'), (6.894067362089746e-15, ' матку'), (6.836453019538678e-15, ' столбу'), (6.7722486202924085e-15, ' гладь'), (6.701017566674327e-15, ' разводку'), (6.651197593114372e-15, ' крыло'), (6.640535947355554e-15, ' пятку'), (6.637777677328022e-15, ' капель'), (6.62601031807305e-15, ' шкафы'), (6.537032050055114e-15, ' цедру'), (6.517469910610266e-15, ' кухню'), (6.178526706503619e-15, ' ведро'), (6.17727337496932e-15, ' стенами'), (6.085803500192241e-15, ' вышку'), (5.9472161796228514e-15, ' поясницу'), (5 ...
#
# Example #2
# word: балка
# gold_sense_id: 2
# context: не страшно. Теперь все -- сказка. Баба-Яга в горах... Волчье логово В Глубокую балку пойти -- за топливом?.. Там стены -- глубокой чашей, небо там -- сине-сине. Кусты
# substitutes & probabilities: [(0.0010332144464393104, ' пещеру'), (5.1470562513327076e-05, ' долину'), (2.1747244789884113e-05, ' реку'), (8.099858014953888e-06, ' деревню'), (3.4426532733348333e-06, ' озеро'), (2.9787087398684663e-06, ' могилу'), (2.53825476277197e-06, ' глубину'), (1.025975613443922e-06, ' Реку'), (9.35756614954228e-07, ' глушь'), (1.7948889461101366e-07, ' Камню'), (1.0948566969733562e-12, ' гору'), (6.903752294165751e-13, ' башню'), (2.6915568955648856e-13, ' чашу'), (1.68825888263644e-13, ' баню'), (1.4279442804111329e-13, ' печь'), (8.243856541531154e-14, ' лужу'), (8.228720844349439e-14, ' стену'), (7.447704177259809e-14, ' яму'), (7.053930974598219e-14, ' Гору'), (6.896943879903569e-14, ' дыру'), (6.660028309218055e-14, ' пропасть'), (6.63211132987613e-14, ' болотку'), (5.85241518251595e-14, ' лесницу'), (5.841295238218739e-14, ' крышу'), (5.382775020313633e-14, ' тайгу'), (4.987293812995139e-14, ' шахту'), (4.8620825898841805e-14, ' трубу'), (4.633113019358194e-14, ' Башню'), (4.4966692494924736e-14, ' поляну'), (4.184124268301011e-14, ' дуплу'), (4.136704483096181e-14, ' рощу'), (3.578102056831362e-14, ' грязь'), (3.423395312440148e-14, ' пустыню'), (3.223167368665793e-14, ' Яму'), (3.138973936748737e-14, ' горы'), (3.0687755498644115e-14, ' доску'), (3.039526308825536e-14, ' коробку'), (2.987395284968983e-14, ' крепость'), (2.8699331582548845e-14, ' лазню'), (2.83840717982565e-14, ' гонку'), (2.8058304714287954e-14, ' Кусты'), (2.4844756771909818e-14, ' печень'), (2.4515025765365742e-14, ' балку'), (2.315285667504447e-14, ' кучу'), (2.2521120759057367e-14, ' церковь'), (2.1080479196715053e-14, ' дамбу'), (2.058964538533004e-14, ' больницу'), (1.991481193248193e-14, ' речку'), (1.8985602302201884e-14, ' равнину'), (1.8141707098081453e-14, ' камень'), (1.718527868391151e-14, ' Волгу'), (1.7077692154015866e-14, ' лугу'), (1.692364356195675e-14, ' точку'), (1.6922294741074866e-14, ' рву'), (1.5566512979996712e-14, ' тень'), (1.509360674437326e-14, ' дань'), (1.3924529793424219e-14, ' щель'), (1.3404344074053742e-14, ' станицу'), (1.2991969186265738e-14, ' череду'), (1.2645918350279132e-14, ' горячку'), (1.253808493798993e-14, ' лаву'), (1.223289765427871e-14, ' арку'), (1.2214853411532387e-14, ' Арку'), (1.218104407203882e-14, ' палатку'), (1.2104687412238186e-14, ' колонну'), (1.2104187625929275e-14, ' ванну'), (1.2084470905504634e-14, ' пущу'), (1.1833613554871135e-14, ' решетку'), (1.177295575507801e-14, ' раку'), (1.1671042251402659e-14, ' беседку'), (1.1569804663548697e-14, ' свалку'), (1.139597236163498e-14, ' чащу'), (1.1314452246895884e-14, ' тару'), (1.1232789509858973e-14, ' Белую'), (1.1117398698873346e-14, ' губу'), (1.0676050506282683e-14, ' сеть'), (1.0666991879433646e-14, ' Камень'), (1.0433022639361997e-14, ' жару'), (1.041088903062724e-14, ' пушку'), (1.0253566988782793e-14, ' сосну'), (1.0130510416707817e-14, ' мастерскую'), (9.929653524982065e-15, ' хату'), (9.783222157992517e-15, ' руину'), (9.654689764536009e-15, ' камню'), (9.520295419612919e-15, ' кухню'), (9.519592742749886e-15, ' Волчье'), (9.335287173249306e-15, ' кабину'), (9.180006427293067e-15, ' сруб'), (8.880671938504417e-15, ' болото'), (8.87597903921744e-15, ' чайку'), (8.70862363668353e-15, ' росу'), (8.680749259608297e-15, ' траву'), (8.623502651911545e-15, ' стоянку'), (8.567677123358206e-15, ' тишу'), (8.564059694140385e-15, ' канализацию'), (8.518870431146145e-15, ' браму'), (8.351576749210625e-15, ' Баню'), (8.082466660638683e-15, ' Гаражу'), (8.033653194214605e-15, ' холму'), (7.943753379208757e-15, ' полю'), (7.93697465104902e-15, ' вершину'), (7.878151910022656e-15, ' драку'), (7.865932700396733e-15, ' Луну'), (7.669722201950566e-15, ' почву'), (7.656856467947193e-15, ' вежу'), (7.510479294653793e-15, ' кошку'), (7.43464474539226e-15, ' Горки'), (7.364148788154296e-15, ' избу'), (7.313108111356615e-15, ' олень'), (7.290264028446848e-15, ' Логово'), (7.148810136513673e-15, ' Воду'), (7.130389548655219e-15, ' Полз ...

# %% [markdown]
# ---

# %%
# we will further work with this dataframe 
# (especially w the columns word, substs_probs, gold_sense_id)
df.head(3)
# Out:
#       index  ...                                       substs_probs
# 0         0  ...  [(0.0003074132201598033,  решетку), (4.1475361...
# 1         1  ...  [(0.020003307469640956,  крыша), (0.0001694636...
# 2         2  ...  [(0.01107819609150758,  колесами), (0.00561495...
# 3         3  ...  [(0.0018431491390275595,  крышей), (0.00144177...
# 4         4  ...  [(0.0040539591647571534,  стену), (0.000310801...
# ...     ...  ...                                                ...
# 3486   3486  ...  [(0.0031943255190048274,  партия), (9.88932979...
# 3487   3487  ...  [(1.0800298370078835e-05,  логике), (9.5142067...
# 3488   3488  ...  [(0.0005675281293156448,  линий), (0.000390070...
# 3489   3489  ...  [(0.01981654824764262,  следы), (0.00222401351...
# 3490   3490  ...  [(0.0005193061257643011,  шутки), (0.000126148...
#
# [3491 rows x 9 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# This objects are used for morphological analysis.

# %%
_ma = MorphAnalyzer()
_ma_cache = {}

# %% [markdown]
# Function `ma(s)` gets a string with one token, deletes spaces before and after token and returns grammatical information about it. If it was met before, we would get information from the special dictionary `_ma_cache`; if it was not, information would be gotten from `pymorphy2`.

# %%
# ma stands for morphological analysis
def ma(s):
    '''
    Gets a string with one token, deletes spaces before and 
    after token and returns grammatical information about it. If it was met 
    before, we would get information from the special dictionary _ma_cache; 
    if it was not, information would be gotten from pymorphy2.
    '''
    s = s.strip()  # get rid of spaces before and after token, 
                   # pytmorphy2 doesn't work with them correctly
    if s not in _ma_cache:
        _ma_cache[s] = _ma.parse(s)
    return _ma_cache[s]

# %%
print('word:', df.loc[0, 'before_subst_prob'][0][1])
# Out:
# word: ,

# %%
print('morphological analysis:', ma(df.loc[0, 'before_subst_prob'][0][1]))
# Out:
# morphological analysis: [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((PunctuationAnalyzer(score=0.9), ','),))]

# %% [markdown]
# Function `get_nf_cnt(substs_probs)` gets substitutes and returns normal forms of substitutes and count of substitutes that coresponds to each normal form.

# %%
def get_nf_cnt(substs_probs):
    '''
    Gets substitutes and returns normal 
    forms of substitutes and count of substitutes that coresponds to 
    each normal form.
    '''
    nf_cnt = Counter(nf for l in substs_probs \
                     for p, s in l for nf in {h.normal_form for h in ma(s)})
    print('\n'.join('%s: %d' % p for p in nf_cnt.most_common(10)))
    return nf_cnt

# %%
nf_cnt = get_nf_cnt(df['before_subst_prob'])
# Out:
# он: 4290
# она: 4087
# весь: 4039
# они: 3924
# и: 3648
# оно: 3613
# тот: 3509
# ,: 3491
# .: 3436
# -: 3407

# %% [markdown]
# Function `get_normal_forms(s, nf_cnt=None)` gets string with one token and returns set of most possible lemmas, all lemmas or one possible lemma.

# %%
def get_normal_forms(s, nf_cnt=None):
    '''
    Gets string with one token and returns set of most possible lemmas, 
    all lemmas or one possible lemma.
    '''
    hh = ma(s)
    if nf_cnt is not None and len(hh) > 1:  # select most common normal form
        h_weights = [nf_cnt[h.normal_form] for h in hh]
        max_weight = max(h_weights)
        return {h.normal_form for i, h in enumerate(hh) \
                if h_weights[i] == max_weight}
    else:
        return {h.normal_form for h in hh}

# %% [markdown]
# For each substitute we choose the most common lemma among all substitutes' lemmas.

# %%
get_normal_forms('жала')
# Out:
# {'жало', 'жать'}

# %%
print('counts:', nf_cnt['жало'], nf_cnt['жать'])
# Out:
# counts: 3 3

# %%
get_normal_forms('жала', nf_cnt)
# Out:
# {'жало', 'жать'}

# %% [markdown]
# Function `preprocess_substs(r, lemmatize=True, nf_cnt=None, exclude_lemmas={}, )` is for preprocessing of substitutions. It gets Series of substitutions and probabilities, exclude lemmas from `exclude_lemmas` if it is not empty and lemmatize them if it is needed.

# %%
def preprocess_substs(r, lemmatize=True, nf_cnt=None, exclude_lemmas={}):
    '''
    For preprocessing of substitutions. It gets Series of substitutions 
    and probabilities, exclude lemmas from exclude_lemmas 
    if it is not empty and lemmatize them if it is needed.
    '''
    res = [s.strip() for p, s in r]
    if exclude_lemmas:
        res1 = [s for s in res 
                if not set(get_normal_forms(s)).intersection(exclude_lemmas)]
        res = res1
    if lemmatize:
        res = [nf for s in res for nf in get_normal_forms(s, nf_cnt)]
    return res

# %% [markdown]
# Here substitutes are preprocessed for clusterization.

# %%
topk = 128 # size of the substitutes' top to use

# %%
substs_texts = df.apply(lambda r: preprocess_substs(r.before_subst_prob[:topk], 
                                                    nf_cnt=nf_cnt, 
                                                    lemmatize=True), 
                        axis=1).str.join(' ')

# %%
tokens_5 = [a[1] for a in df.loc[0, 'before_subst_prob']]
print(' '.join(tokens_5))
# Out:
# , плиту часть . плоскость ; стену плиты и - потолок плит башню яму панель – — стенку ( доску группу балк конструкцию стены плита платформу плоскости перекрытие балки поверхность лестницу ту зону крышу палубу шахту : живопись ее клетку ткань … / пол опору секцию технику пару на балок комнату ##ку стене перекрытия машину стен систему части ' композицию сферу галерею площадку " ярус мебель такую опоры кору ячейку кучу ступень а точку станцию кость консоль нее поверхности по посуду девушку камеру другую или кладку нижнюю постройку ##лю ) установку структуру стена ##у решетку свода строение землю плитами корзину роспись одежду тумб в этаж балка что колонку балками палату работу верев ##ую траншею цоколь раму каркас её ось стойку линию вторую долю трубу долину одну ##ь плитой третью прочность не карниз дно ведущую травму банку глубину консоли половину толщину бумагу шахты с колонну ферму металлическую ##ную под погоду перекрытий

# %%
print('word:', df.loc[0, 'word'], 
      '\nlemmas of substitutes:', substs_texts[0])
# Out:
# word: балка
# lemmas of substitutes: , плита часть . плоскость ; стена плита и - потолок плита башня яма ям панель – — стенка ( доска группа балк конструкция стена плита платформа плоскость перекрытие балка поверхность лестница тот зона крыша палуба шахта : живопись она клетка ткань … / пол опора секция техника пара на балка комната ##ка стена перекрытие машина стена система часть ' композиция сфера галерея площадка " ярус мебель такой опора кора ячейка куча ступень а точка станция кость консоль она поверхность по посуда девушка камера другой или кладка нижний постройка ##ить ) установка структура стена ##у решётка свод строение земля плита корзина роспись одежда тумба в этаж балка что колонок колонка балка палата работа верёва верёв ##ий траншея цоколь рам рама каркас она ось стойка линия второй доля труба долина один ##ь плита

# %% [markdown]
# `substs_texts` is the set with strings of lemmatized substitutes for each example.

# %%
substs_texts
# Out:
# 0       , плита часть . плоскость ; стена плита и - по...
# 1       , – - — : ( ; и . … село упасть ! весь вот да ...
# 2       , связь узел продольный поперечный балка ( — и...
# 3       , ( ; — . часть и поперечный она - продольный ...
# 4       , он дерево машина она куча стена яма ям . рек...
#                               ...
# 3486    , партия ; они … . — он - весь : они этот этот...
# 3487    - , – русский письмо список — текст латынь сти...
# 3488    , - ; . – : " — и ) ( … штука год ! а или + пл...
# 3489    , : проблема ( " - ) и . недостаток штамп ; « ...
# 3490    , элемент клише жанр стиль эпизод драма комеди...
# Length: 3491, dtype: object

# %% [markdown]
# ## Clusterization and ARI calculating

# %% [markdown]
# Paramters which are used for vectorization of substitutes and clusterization.

# %%
vectorizer = 'TfidfVectorizer'
lemmatize = True
analyzer = 'word'
min_df = 0.05
max_df = 0.95
ngram_range = (1, 1)
ncs=(2,10)

# %%
vec = eval(vectorizer)(token_pattern=r"(?u)\b\w+\b", 
                       min_df=min_df, max_df=max_df, 
                       analyzer=analyzer, ngram_range=ngram_range)

# %%
# the list of words of interest. 
# note that all the dataset entries refer to one of these words
df.word.unique()
# Out:
# array(['балка', 'вид', 'винт', 'горн', 'губа', 'жаба', 'клетка', 'крыло',
#        'купюра', 'курица', 'лавка', 'лайка', 'лев', 'лира', 'мина',
#        'мишень', 'обед', 'оклад', 'опушка', 'полис', 'пост', 'поток',
#        'проказа', 'пропасть', 'проспект', 'пытка', 'рысь', 'среда',
#        'хвост', 'штамп'], dtype=object)

# %% [markdown]
# Function `max_ari` gets data and substitutions (and some parameters like `vectorizer` and parameters for clusterization). Here for each unique word substitutions are vectorized and senses are clusterized.

# %%
df[['case_enc', 'number_enc', 'dep_enc']].to_numpy()
# Out:
# array([[0.14285714, 0.5       , 0.        ],
#        [0.28571429, 0.5       , 0.04761905],
#        [0.42857143, 1.        , 0.0952381 ],
#        ...,
#        [0.57142857, 1.        , 0.23809524],
#        [0.14285714, 1.        , 0.04761905],
#        [0.14285714, 1.        , 0.        ]])

# %%
def max_ari(df, X, ncs,
            affinity='cosine', linkage='average', vectorizer=None):
    '''
    Gets data and substitutions (and some parameters 
    like vectorizer and parameters for clusterization). 
    Here for each unique word substitutions 
    are vectorized and senses are clusterized.
    It returns metrics of clusterization.
    '''
    sdfs = []
    for word in df.word.unique():
        # collecting examples for the word
        mask = (df.word == word)
#         print(mask)
        # vectors for substitutions
        vectors = X[mask] if vectorizer is None \
        else vectorizer.fit_transform(X[mask]).toarray()
        vectors_ling = np.hstack((vectors, df[mask][['case_enc', 'number_enc', 'dep_enc']].to_numpy()))
        # ids of senses of the examples
        gold_sense_ids = df.gold_sense_id[mask]
        gold_sense_ids = None if gold_sense_ids.isnull().any() \
        else gold_sense_ids

        # clusterization (ari is kept in sdf along with other info)
        best_clids, sdf, _ = clusterize_search(word, vectors_ling, gold_sense_ids, 
                ncs=ncs,
                affinity=affinity, linkage=linkage)
        df.loc[mask, 'predict_sense_id'] = best_clids # result ids of clusters
        sdfs.append(sdf)
    
    return sdfs

# %% [markdown]
# Function `clusterize_search` gets word, vectors, gold_sense_ids and provides AgglomerativeClustering of vectors of substitutes for each example of one word.
#
#
# Than it calculates [ARI](https://en.wikipedia.org/wiki/Rand_index) and [silhouette scores](https://en.wikipedia.org/wiki/Silhouette_(clustering)).

# %%
def clusterize_search(word, vecs, gold_sense_ids = None, 
                      ncs=list(range(1, 5, 1)) + list(range(5, 12, 2)),
            affinity='cosine', linkage='average', print_topf=None,
            generate_pictures_df = False,  corpora_ids = None):
    '''
    Gets word, vectors, gold_sense_ids and provides AgglomerativeClustering.
    '''
  
    sdfs = []
    tmp_dfs = []

    # adding 1 to zero vectors, because there will be problems (all-zero vectorized entries), if they remain zero
    # this introduces a new dimension with possible values 
    # 1 -- all the other coords are zeros
    # 0 -- other coords are not all-zeros
    zero_vecs = ((vecs ** 2).sum(axis=-1) == 0)
    if zero_vecs.sum() > 0:
        vecs = np.concatenate((vecs, 
                               zero_vecs[:, np.newaxis].astype(vecs.dtype)), 
                              axis=-1)

    best_clids = None
    best_silhouette = 0
    distances = []

    # matrix with computed distances between each pair of the two collections of inputs
    distance_matrix = cdist(vecs, vecs, metric=affinity)
    distances.append(distance_matrix)

    for nc in ncs:
        # clusterization
        clr = AgglomerativeClustering(affinity='precomputed', 
                                      linkage=linkage, 
                                      n_clusters=nc)
        clids = clr.fit_predict(distance_matrix) if nc > 1 \
        else np.zeros(len(vecs))

        # computing metrics
        ari = ARI(gold_sense_ids, clids) if gold_sense_ids is not None else np.nan
        sil_cosine = -1. if len(np.unique(clids)) < 2 else silhouette_score(vecs, clids, metric='cosine')
        sil_euclidean = -1. if len(np.unique(clids)) < 2 else silhouette_score(vecs, clids, metric='euclidean')
        
        # vc like 5/4/3 says that 
        # there are 5 examples w golden_id=id1; 
        # there are 4 examples w golden_id=id2; 
        # there are 3 examples w golden_id=id3; 
        # e.g. вид 4/3/2 means that there were 
        # 4 examples with вид==view; 3 examples .==type; 2 examples .==specie
        vc = '' if gold_sense_ids is None else '/'.join(
            np.sort(pd.value_counts(gold_sense_ids).values)[::-1].astype(str))
        
        if sil_cosine > best_silhouette:
            best_silhouette = sil_cosine
            best_clids = clids

        # metrics for each word
        sdf = pd.DataFrame({'ari': ari,
                            'word': word, 'nc': nc,
                            'sil_cosine': sil_cosine,
                            'sil_euclidean': sil_euclidean,
                            'vc': vc,
                            'affinity': affinity, 'linkage': linkage}, \
                           index=[0])

        sdfs.append(sdf)
  
    sdf = pd.concat(sdfs, ignore_index=True)

    return best_clids, sdf, distances

# %%
sdfs = max_ari(df, 
               substs_texts, 
               ncs=range(*ncs), 
               affinity='cosine', 
               linkage='average', 
               vectorizer=vec)

# %% [markdown]
# Metrics for one unique word.

# %%
sdfs[0]
# Out:
#         ari   word  nc  sil_cosine  sil_euclidean     vc affinity  linkage
# 0 -0.031687  балка   2    0.166024       0.026075  81/38   cosine  average
# 1  0.001893  балка   3    0.146471       0.015558  81/38   cosine  average
# 2 -0.005198  балка   4    0.142668       0.016125  81/38   cosine  average
# 3  0.010129  балка   5    0.127995       0.010891  81/38   cosine  average
# 4 -0.030015  балка   6    0.130211       0.016721  81/38   cosine  average
# 5 -0.029457  балка   7    0.116823       0.007606  81/38   cosine  average
# 6 -0.029640  балка   8    0.114049       0.005748  81/38   cosine  average
# 7 -0.032733  балка   9    0.108765       0.004823  81/38   cosine  average

# %%
def metrics(sdfs):
    # all metrics for each unique word
    sdf = pd.concat(sdfs, ignore_index=True)
    # groupby is docuented to preserve inside group order
    res = sdf.sort_values(by='ari').groupby(by='word').last()
    # maxari for fixed hypers
    fixed_hypers = sdf.groupby(['affinity', 
                                'linkage', 
                                'nc']).agg({'ari': np.mean}).reset_index()
    idxmax = fixed_hypers.ari.idxmax()
    res_df = fixed_hypers.loc[idxmax:idxmax].copy()
    res_df = res_df.rename(columns=lambda c: 'fh_maxari' if c == 'ari' \
                           else 'fh_' + c)
    res_df['maxari'] = res.ari.mean()

    for metric in [c for c in sdf.columns if c.startswith('sil')]:
        res_df[metric+'_ari'] = sdf.sort_values(by=metric).groupby(by='word').last().ari.mean()

    return res_df, res, sdf

# %%
res_df, res, sdf = metrics(sdfs)

# %% [markdown]
# ## Results

# %% [markdown]
# General metrics for the configuration.

# %%
res_df
# Out:
#   fh_affinity fh_linkage  fh_nc  fh_maxari    maxari  sil_cosine_ari  \
# 1      cosine    average      3   0.156143  0.274359        0.148206
#
#    sil_euclidean_ari
# 1           0.132526

# %% [markdown]
# Metrics for each word.

# %%
res
# Out:
#                ari  nc  sil_cosine  sil_euclidean                 vc affinity  \
# word
# балка     0.010129   5    0.127995       0.010891              81/38   cosine
# вид       0.000641   5    0.123047       0.012779            38/36/3   cosine
# винт      0.205065   8    0.111291       0.002074         67/39/16/1   cosine
# горн     -0.024567   2    0.114606       0.013441            30/20/1   cosine
# губа      0.558723   2    0.284611       0.144102            132/3/2   cosine
# жаба      0.286801   6    0.129432       0.035217          79/27/9/6   cosine
# клетка    0.222721   7    0.161020       0.016573      96/38/7/4/4/1   cosine
# крыло     0.427808   9    0.165801       0.043732  51/19/7/5/4/3/1/1   cosine
# купюра    0.095901   3    0.237494       0.054303             138/12   cosine
# курица    0.160638   6    0.148996       0.037489              62/31   cosine
# лавка     0.078020   4    0.177572       0.036044              82/67   cosine
# лайка     0.069730   3    0.121972       0.044923              81/18   cosine
# лев       0.149995   9    0.030434      -0.020764           36/4/2/2   cosine
# лира      0.917247   2    0.177576       0.082736              33/16   cosine
# мина      0.561042   4    0.185105       0.043169            51/12/2   cosine
# мишень    0.027322   2    0.108280       0.029773              88/33   cosine
# обед      0.160037   3    0.131864       0.035347         62/19/17/2   cosine
# оклад     0.724031   3    0.141747       0.019007            137/5/4   cosine
# опушка    0.286867   9    0.194005       0.053406              142/6   cosine
# полис     0.790700   2    0.180630       0.064796              139/3   cosine
# пост      0.061970   3    0.095967       0.000821       98/32/10/2/2   cosine
# поток     0.009090   9    0.083166      -0.004315             124/12   cosine
# проказа   0.117809   7    0.146516       0.012365              95/51   cosine
# пропасть  0.452982   5    0.086450       0.027115          92/25/7/3   cosine
# проспект  0.422761   2    0.224519       0.098331         117/12/6/4   cosine
# пытка     0.299888   9    0.194107       0.018920             116/27   cosine
# рысь      0.244397   2    0.247240       0.149417              82/38   cosine
# среда     0.412345   7    0.219465       0.088876        52/47/32/13   cosine
# хвост     0.334068   6    0.099196       0.026803         100/12/8/1   cosine
# штамп     0.166612   9    0.102393       0.012480          47/45/3/1   cosine
#
#           linkage
# word
# балка     average
# вид       average
# винт      average
# горн      average
# губа      average
# жаба      average
# клетка    average
# крыло     average
# купюра    average
# курица    average
# лавка     average
# лайка     average
# лев       average
# лира      average
# мина      average
# мишень    average
# обед      average
# оклад     average
# опушка    average
# полис     average
# пост      average
# поток     average
# проказа   average
# пропасть  average
# проспект  average
# пытка     average
# рысь      average
# среда     average
# хвост     average
# штамп     average

# %%
from conllu import parse

data = """
# text = The quick brown fox jumps over the lazy dog.
1   The     the    DET    DT   Definite=Def|PronType=Art   4   det     _   _
2   quick   quick  ADJ    JJ   Degree=Pos                  4   amod    _   _
3   brown   brown  ADJ    JJ   Degree=Pos                  4   amod    _   _
4   fox     fox    NOUN   NN   Number=Sing                 5   nsubj   _   _
5   jumps   jump   VERB   VBZ  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin   0   root    _   _
6   over    over   ADP    IN   _                           9   case    _   _
7   the     the    DET    DT   Definite=Def|PronType=Art   9   det     _   _
8   lazy    lazy   ADJ    JJ   Degree=Pos                  9   amod    _   _
9   dog     dog    NOUN   NN   Number=Sing                 5   nmod    _   SpaceAfter=No
10  .       .      PUNCT  .    _                           5   punct   _   _

# text = The quick brown fox jumps over the lazy dog.
1   The     the    DET    DT   Definite=Def|PronType=Art   4   det     _   _
2   quick   quick  ADJ    JJ   Degree=Pos                  4   amod    _   _
3   brown   brown  ADJ    JJ   Degree=Pos                  4   amod    _   _
4   fox     fox    NOUN   NN   Number=Sing                 5   nsubj   _   _
5   jumps   jump   VERB   VBZ  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin   0   root    _   _
6   over    over   ADP    IN   _                           9   case    _   _
7   the     the    DET    DT   Definite=Def|PronType=Art   9   det     _   _
8   lazy    lazy   ADJ    JJ   Degree=Pos                  9   amod    _   _
9   dog     dog    NOUN   NN   Number=Sing                 5   nmod    _   SpaceAfter=No
10  .       .      PUNCT  .    _                           5   punct   _   _

# text = The quick brown fox jumps over the lazy dog.
1   The     the    DET    DT   Definite=Def|PronType=Art   4   det     _   _
2   quick   quick  ADJ    JJ   Degree=Pos                  4   amod    _   _
3   brown   brown  ADJ    JJ   Degree=Pos                  4   amod    _   _
4   fox     fox    NOUN   NN   Number=Sing                 5   nsubj   _   _
5   jumps   jump   VERB   VBZ  Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin   0   root    _   _
6   over    over   ADP    IN   _                           9   case    _   _
7   the     the    DET    DT   Definite=Def|PronType=Art   9   det     _   _
8   lazy    lazy   ADJ    JJ   Degree=Pos                  9   amod    _   _
9   dog     dog    NOUN   NN   Number=Sing                 5   nmod    _   SpaceAfter=No
10  .       .      PUNCT  .    _                           5   punct   _   _


"""

# %%
from conllu import parse_tree

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/c2/mq2yd_150sdd11x87yqcqq0c0000gq/T/ipykernel_35783/1425390613.py in <module>
# ----> 1 parse_tree(data)[0].filter(id=4)
#
# AttributeError: 'TokenTree' object has no attribute 'filter'

# %%
parse_tree(data)[0].children[0].children
# Out:
# [TokenTree<token={id=1, form=The}, children=None>,
#  TokenTree<token={id=2, form=quick}, children=None>,
#  TokenTree<token={id=3, form=brown}, children=None>]

# %%
from smart_open import open

# %%
target_words = {'в':''}
morph_properties = {w: {} for w in target_words}
syntax_properties = {w: {} for w in target_words}


dep_dict = {}
rels = []
for line in open('test.conllu', 'r'): #('/Users/a19336136/rnc_cluster/parsed/corpus1.conllu.gz', "r"):
    print(line)
    if not line.strip():
        continue
    if line.startswith("# "):
        if rels:
            for idx, rel, lemma in rels:
                if idx in dep_dict.keys():
                    rel_set = rel + '|' + '|'.join(sorted(dep_dict[idx]))
                else:
                    rel_set = rel
                if rel_set not in syntax_properties[lemma]:
                    syntax_properties[lemma][rel_set] = 0
                syntax_properties[lemma][rel_set] += 1
        rels = []
        dep_dict = {}        
        continue
    (
        identifier,
        form,
        lemma,
        pos,
        xpos,
        feats,
        head,
        rel,
        enh,
        misc,
    ) = line.strip().split('\t')
    lemma = lemma.lower()
    if head not in dep_dict.keys():
        dep_dict[head] = []
    dep_dict[head].append(rel)

    if lemma in target_words:
        if target_words[lemma]:
            if pos != target_words[lemma]:
                continue
        if feats not in morph_properties[lemma]:
            morph_properties[lemma][feats] = 0
        morph_properties[lemma][feats] += 1
        rels.append((identifier, rel, lemma))

for idx, rel, lemma in rels:  
    rel_set = rel + '|' + '|'.join(sorted(dep_dict[idx]))
    if rel_set not in syntax_properties[lemma]:
            syntax_properties[lemma][rel_set] = 0
    syntax_properties[lemma][rel_set] += 1
rels = []
dep_dict = {}
# Out:
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Материал для скульптора.
#
# 1	Материал	МАТЕРИАЛ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	для	ДЛЯ	ADP	IN	_	3	case	_	_
#
# 3	скульптора	СКУЛЬПТОР	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing	1	nmod	_	SpaceAfter=No
#
# 4	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Виноградов Михаил.
#
# 1	Виноградов	ВИНОГРАДОВ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	Михаил	МИХАИЛ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	flat	_	SpaceAfter=No
#
# 3	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Материал для скульптора.
#
# 1	Материал	МАТЕРИАЛ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	для	ДЛЯ	ADP	IN	_	3	case	_	_
#
# 3	скульптора	СКУЛЬПТОР	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing	1	nmod	_	SpaceAfter=No
#
# 4	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Политологи решили сохранить Госдуму
#
# 1	Политологи	Политологи	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	2	nsubj	_	_
#
# 2	решили	РЕШИТЬ	VERB	VBC	Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 3	сохранить	СОХРАНИТЬ	VERB	VB	Aspect=Perf|VerbForm=Inf	2	xcomp	_	_
#
# 4	Госдуму	Госдуму	PROPN	NNP	Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing	3	iobj	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Дискуссия политологов и политтехнологов проходи...
#
# 1	Дискуссия	Дискуссия	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	5	nsubj	_	_
#
# 2	политологов	политологов	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur	1	nmod	_	_
#
# 3	и	И	CCONJ	CC	_	4	cc	_	_
#
# 4	политтехнологов	политтехнологов	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	2	conj	_	_
#
# 5	проходи	прохОДИ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	0	root	_	SpaceAfter=No
#
# 6	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Декларированная цель этого проекта-- обсуждать ...
#
# 1	Декларированная	Декларированная	VERB	VBNL	Animacy=Inan|Aspect=Perf|Case=Nom|Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	2	acl	_	_
#
# 2	цель	ЦЕЛЬ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	0	root	_	_
#
# 3	этого	ЭТОТ	DET	DT	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	4	det	_	_
#
# 4	проекта	ПРОЕКТ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	2	nmod	_	SpaceAfter=No
#
# 5	-	-	PUNCT	-	_	4	goeswith	_	SpaceAfter=No
#
# 6	-	-	PUNCT	-	_	4	goeswith	_	_
#
# 7	обсуждать	обсуждать	VERB	VB	Aspect=Imp|VerbForm=Inf	4	goeswith	_	_
#
# 8	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = На этот раз участники занялись прогнозами относ...
#
# 1	На	НА	ADP	IN	_	3	case	_	_
#
# 2	этот	ЭТОТ	DET	DT	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	3	det	_	_
#
# 3	раз	РАЗ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	5	obl	_	_
#
# 4	участники	УЧАСТНИК	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	5	nsubj	_	_
#
# 5	занялись	занялись	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 6	прогнозами	прогнозами	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur	5	iobj	_	_
#
# 7	относ	относ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	6	nmod	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Политологи положительно оценили работу Думы: он...
#
# 1	Политологи	Политологи	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	3	nsubj	_	_
#
# 2	положительно	ПОЛОЖИТЕЛЬНО	ADV	RB	_	3	advmod	_	_
#
# 3	оценили	оЦЕНИТЬ	VERB	VBC	Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 4	работу	РАБОТА	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	3	obj	_	_
#
# 5	Думы	дУМЫ	PROPN	NNP	Animacy=Inan|Case=Acc|Gender=Fem|Number=Plur	4	appos	_	SpaceAfter=No
#
# 6	:	:	PUNCT	:	_	3	punct	_	_
#
# 7	он	ОН	PRON	PRP	Case=Nom|Gender=Masc|Number=Sing|Person=3	8	nsubj	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Опасения, которые высказывались по поводу профе...
#
# 1	Опасения	ОПАСЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur	0	root	_	SpaceAfter=No
#
# 2	,	,	PUNCT	,	_	4	punct	_	_
#
# 3	которые	КОТОРЫЙ	PRON	AWP	Animacy=Inan|Case=Nom|Number=Plur	4	nsubj	_	_
#
# 4	высказывались	высказывались	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid	1	acl:relcl	_	_
#
# 5	по	ПО	ADP	IN	_	6	case	_	_
#
# 6	поводу	ПОВОД	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing	4	obl	_	_
#
# 7	профе	проФА	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Fem|Number=Sing	4	obl	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = И вообще,«появилась схема, она работает, решают...
#
# 1	И	И	CCONJ	CC	_	5	cc:preconj	_	_
#
# 2	вообще	ВООБЩЕ	ADV	RB	_	5	discourse	_	SpaceAfter=No
#
# 3	,	,	PUNCT	,	_	2	punct	_	SpaceAfter=No
#
# 4	«	«	PUNCT	,	_	2	punct	_	SpaceAfter=No
#
# 5	появилась	ПОЯВИТЬСЯ	VERB	VBC	Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 6	схема	СХЕМА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	5	nsubj	_	SpaceAfter=No
#
# 7	,	,	PUNCT	,	_	5	punct	_	_
#
# 8	она	ОНА	PRON	PRP	Case=Nom|Gender=Fem|Number=Sing|Person=3	9	nsubj	_	_
#
# 9	работает	РАБОТАТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	5	parataxis	_	SpaceAfter=No
#
# 10	,	,	PUNCT	,	_	11	punct	_	_
#
# 11	решают	решают	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	9	conj	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 14	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Весенняя сессия-- доказательство изменения отно...
#
# 1	Весенняя	Весенняя	ADJ	JJL	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	2	amod	_	_
#
# 2	сессия	сессия	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	5	nsubj	_	SpaceAfter=No
#
# 3	-	-	PUNCT	-	_	2	goeswith	_	SpaceAfter=No
#
# 4	-	-	PUNCT	-	_	2	goeswith	_	_
#
# 5	доказательство	доказательство	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	0	root	_	_
#
# 6	изменения	ИЗМЕНЕНИЕ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	5	nmod	_	_
#
# 7	отно	отно	ADV	RB	_	8	advmod	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Больше времени заняло обсуждение негативных мом...
#
# 1	Больше	МНОГО	ADV	RBR	Degree=Cmp	3	advmod	_	_
#
# 2	времени	ВРЕМЯ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	1	nmod	_	_
#
# 3	заняло	заняло	VERB	VBC	Aspect=Imp|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 4	обсуждение	обсуждение	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	3	obj	_	_
#
# 5	негативных	негативных	ADJ	JJL	Animacy=Inan|Case=Gen|Number=Plur	6	amod	_	_
#
# 6	мом	мом	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	4	iobj	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Заявление одного из участников дискуссии, полит...
#
# 1	Заявление	ЗАЯВЛЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	0	root	_	_
#
# 2	одного	ОДИН	NUM	CD	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing|NumType=Card	7	nummod	_	_
#
# 3	из	ИЗ	ADP	IN	_	4	case	_	_
#
# 4	участников	УЧАСТНИК	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur	2	nmod	_	_
#
# 5	дискуссии	дискуссии	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	4	nmod	_	SpaceAfter=No
#
# 6	,	,	PUNCT	,	_	2	punct	_	_
#
# 7	полит	полит	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	1	nmod	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Один из собравшихся облек происходящий между ис...
#
# 1	Один	ОДИН	NUM	CD	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing|NumType=Card	0	root	_	_
#
# 2	из	ИЗ	ADP	IN	_	4	case	_	_
#
# 3	собравшихся	собравшихся	VERB	VBNL	Animacy=Anim|Aspect=Perf|Case=Acc|Number=Plur|Tense=Past|VerbForm=Part|Voice=Act	4	acl	_	_
#
# 4	облек	оБЛЕК	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	1	nmod	_	_
#
# 5	происходящий	происходящий	VERB	VBNL	Animacy=Inan|Aspect=Imp|Case=Nom|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Act	4	acl	_	_
#
# 6	между	МЕЖДУ	ADP	IN	_	7	case	_	_
#
# 7	ис	ис	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	5	obl	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Руководитель фонда«Общественное мнение» социоло...
#
# 1	Руководитель	РУКОВОДИТЕЛЬ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	7	nsubj	_	_
#
# 2	фонда	ФОНД	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	1	nmod	_	SpaceAfter=No
#
# 3	«	«	PUNCT	,	_	7	punct	_	SpaceAfter=No
#
# 4	Общественное	Общественное	ADJ	JJL	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	5	amod	_	_
#
# 5	мнение	МНЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	7	nsubj	_	SpaceAfter=No
#
# 6	»	»	PUNCT	,	_	5	punct	_	_
#
# 7	социоло	социоло	VERB	VBC	Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Глеб Павловский заметил, что нижней палате парл...
#
# 1	Глеб	глеб	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	3	nsubj	_	_
#
# 2	Павловский	Павловский	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	flat	_	_
#
# 3	заметил	ЗАМЕТИТЬ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	8	punct	_	_
#
# 5	что	ЧТО	SCONJ	IN	_	8	mark	_	_
#
# 6	нижней	НИЖНИЙ	ADJ	JJL	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	7	amod	_	_
#
# 7	палате	ПАЛАТА	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	8	obj	_	_
#
# 8	парл	пАРЛ	VERB	VBC	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	3	ccomp	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Практически все присутствовавшие утверждали, чт...
#
# 1	Практически	ПРАКТИЧЕСКИ	ADV	RB	_	4	advmod	_	_
#
# 2	все	ВЕСЬ	DET	DT	Animacy=Anim|Case=Nom|Number=Plur	3	det	_	_
#
# 3	присутствовавшие	присутствовавшие	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	4	nsubj	_	_
#
# 4	утверждали	утверждали	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 5	,	,	PUNCT	,	_	6	punct	_	_
#
# 6	чт	чТ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	conj	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Такой шаг был бы ударом для идущего сейчас полн...
#
# 1	Такой	ТАКОЙ	DET	WDT	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	2	det	_	_
#
# 2	шаг	ШАГ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	_
#
# 3	был	БЫТЬ	AUX	VBC	Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	5	cop	_	_
#
# 4	бы	БЫ	PART	RP	_	5	discourse	_	_
#
# 5	ударом	УДАР	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	0	root	_	_
#
# 6	для	ДЛЯ	ADP	IN	_	7	case	_	_
#
# 7	идущего	идущего	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	5	nmod	_	_
#
# 8	сейчас	сейЧАС	ADV	RB	_	9	advmod	_	_
#
# 9	полн	полн	VERB	VBNH	Animacy=Inan|Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	5	nmod	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Кроме того, как заметил Вячеслав Никонов, прези...
#
# 1	Кроме	КРОМЕ	ADP	IN	_	2	case	_	_
#
# 2	того	ТО	PRON	DT	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	5	obl	_	SpaceAfter=No
#
# 3	,	,	PUNCT	,	_	5	punct	_	_
#
# 4	как	КАК	SCONJ	IN	_	5	mark	_	_
#
# 5	заметил	ЗАМЕТИТЬ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 6	Вячеслав	ВЯЧЕСЛАВ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	_
#
# 7	Никонов	Никонов	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	flat	_	SpaceAfter=No
#
# 8	,	,	PUNCT	,	_	5	punct	_	_
#
# 9	прези	прези	ADV	AFX	_	5	advmod	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Коммунисты вполне могут опрокинуть все расчеты ...
#
# 1	Коммунисты	Коммунисты	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	3	nsubj	_	_
#
# 2	вполне	ВПОЛНЕ	ADV	RB	_	3	advmod	_	_
#
# 3	могут	МОЧЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 4	опрокинуть	опрокинуть	VERB	VB	Aspect=Perf|VerbForm=Inf	3	xcomp	_	_
#
# 5	все	ВЕСЬ	DET	DT	Animacy=Inan|Case=Acc|Number=Plur	6	det	_	_
#
# 6	расчеты	расчеты	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur	4	obj	_	_
#
# 7	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Все сошлись на том, что палата должна обновлять...
#
# 1	Все	ВЕСЬ	DET	DT	Animacy=Inan|Case=Nom|Number=Plur	2	nsubj	_	_
#
# 2	сошлись	сошлись	VERB	VBC	Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 3	на	НА	ADP	IN	_	4	case	_	_
#
# 4	том	ТО	PRON	DT	Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing	2	obl	_	SpaceAfter=No
#
# 5	,	,	PUNCT	,	_	8	punct	_	_
#
# 6	что	ЧТО	SCONJ	IN	_	8	mark	_	_
#
# 7	палата	паЛАТА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	8	nsubj	_	_
#
# 8	должна	ДОЛЖЕН	ADJ	JJH	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing|Variant=Short	2	ccomp	_	_
#
# 9	обновлять	обновлять	VERB	VB	Aspect=Imp|VerbForm=Inf	8	xcomp	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Депутатам«нужно вести конструктивную игру на со...
#
# 1	Депутатам	Депутатам	NOUN	NN	Animacy=Anim|Case=Dat|Gender=Masc|Number=Plur	3	iobj	_	SpaceAfter=No
#
# 2	«	«	PUNCT	,	_	1	punct	_	SpaceAfter=No
#
# 3	нужно	НУЖНО	VERB	PRED	Degree=Pos	0	root	_	_
#
# 4	вести	ВЕСТИ	VERB	VB	Aspect=Imp|VerbForm=Inf	3	xcomp	_	_
#
# 5	конструктивную	конструктивную	ADJ	JJL	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	6	amod	_	_
#
# 6	игру	ИГРА	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	4	obj	_	_
#
# 7	на	НА	ADP	IN	_	8	case	_	_
#
# 8	со	СО	PROPN	NNP	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	4	obl	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Вразрез с общим мнением пошел Андрей Федоров из...
#
# 1	Вразрез	Вразрез	ADP	IN	_	4	case	_	_
#
# 2	с	С	ADP	IN	_	4	case	_	_
#
# 3	общим	ОБЩИЙ	ADJ	JJL	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	4	amod	_	_
#
# 4	мнением	мнением	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	5	obl	_	_
#
# 5	пошел	ПОЙТИ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 6	Андрей	АНДРЕЙ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	_
#
# 7	Федоров	Федоров	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	flat	_	_
#
# 8	из	ИЗ	ADP	IN	_	9	case	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Он заявил, что работа палаты этой осенью не име...
#
# 1	Он	ОН	PRON	PRP	Case=Nom|Gender=Masc|Number=Sing|Person=3	2	nsubj	_	_
#
# 2	заявил	ЗАЯВИТЬ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 3	,	,	PUNCT	,	_	10	punct	_	_
#
# 4	что	ЧТО	SCONJ	IN	_	10	mark	_	_
#
# 5	работа	РАБОТА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	10	nsubj	_	_
#
# 6	палаты	палаты	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	5	nmod	_	_
#
# 7	этой	ЭТОТ	DET	DT	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	8	det	_	_
#
# 8	осенью	ОСЕНЬ	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing	10	advmod	_	_
#
# 9	не	НЕ	PART	NEG	Polarity=Neg	10	advmod	_	_
#
# 10	име	ИМА	PROPN	NNP	Animacy=Anim|Case=Loc|Gender=Fem|Number=Sing	2	ccomp	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Он привязал желательность роспуска палаты к нео...
#
# 1	Он	ОН	PRON	PRP	Case=Nom|Gender=Masc|Number=Sing|Person=3	2	nsubj	_	_
#
# 2	привязал	привязал	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 3	желательность	желательность	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	2	obj	_	_
#
# 4	роспуска	РОСПУСК	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	3	nmod	_	_
#
# 5	палаты	палаты	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	4	nmod	_	_
#
# 6	к	К	ADP	IN	_	7	case	_	_
#
# 7	нео	нЕО	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	3	nmod	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Политолог предлагает не роспуск, а самороспуск ...
#
# 1	Политолог	Политолог	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	2	nsubj	_	_
#
# 2	предлагает	ПРЕДЛАГАТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 3	не	НЕ	PART	NEG	Polarity=Neg	4	advmod	_	_
#
# 4	роспуск	роСПУСК	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	2	obj	_	SpaceAfter=No
#
# 5	,	,	PUNCT	,	_	7	punct	_	_
#
# 6	а	А	CCONJ	CC	_	7	cc	_	_
#
# 7	самороспуск	самороСПУСК	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	2	conj	_	_
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = По его мнению, досрочные выборы Госдумы позволя...
#
# 1	По	ПО	ADP	IN	_	3	case	_	_
#
# 2	его	ЕГО	DET	PRP$	Person=3	3	det	_	_
#
# 3	мнению	МНЕНИЕ	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing	4	nmod	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	6	punct	_	_
#
# 5	досрочные	НОЧдосрОЙ	ADJ	JJL	Animacy=Inan|Case=Nom|Number=Plur	6	amod	_	_
#
# 6	выборы	ВЫБОРЫ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	0	root	_	_
#
# 7	Госдумы	ГосдУМЫ	PROPN	NNP	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	6	nmod	_	_
#
# 8	позволя	позволя	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	7	nmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = И если вопрос с Думой будет решен заранее, то в...
#
# 1	И	И	CCONJ	CC	_	7	cc:preconj	_	_
#
# 2	если	ЕСЛИ	SCONJ	IN	_	7	mark	_	_
#
# 3	вопрос	ВОПРОС	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	7	nsubj:pass	_	_
#
# 4	с	С	ADP	IN	_	5	case	_	_
#
# 5	Думой	Думой	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	3	nmod	_	_
#
# 6	будет	БЫТЬ	AUX	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	7	aux:pass	_	_
#
# 7	решен	реШЕН	VERB	VBNH	Animacy=Anim|Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	0	root	_	_
#
# 8	заранее	ЗАРАНЕЕ	ADV	RB	_	7	advmod	_	SpaceAfter=No
#
# 9	,	,	PUNCT	,	_	7	punct	_	_
#
# 10	то	ТО	ADV	RB	_	7	advmod	_	_
#
# 11	в	В	ADP	IN	_	12	case	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 14	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Речкалов Вадим.
#
# 1	Речкалов	Речкалов	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	Вадим	ВадИМ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	flat	_	SpaceAfter=No
#
# 3	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Комендантом Чечни назначен милицейский генерал
#
# 1	Комендантом	КОМЕНДАНТ	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	3	iobj	_	_
#
# 2	Чечни	Чечни	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	1	nmod	_	_
#
# 3	назначен	НАЗНАЧИТЬ	VERB	VBNH	Animacy=Anim|Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	0	root	_	_
#
# 4	милицейский	милицейский	ADJ	JJL	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	5	amod	_	_
#
# 5	генерал	ГЕНЕРАЛ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	3	nsubj:pass	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В Чечне новое кадровое назначение.
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	Чечне	Чечне	PROPN	NNP	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	5	nmod	_	_
#
# 3	новое	НОВЫЙ	ADJ	JJL	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	5	amod	_	_
#
# 4	кадровое	кадровое	ADJ	JJL	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	5	amod	_	_
#
# 5	назначение	НАЗНАЧЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	0	root	_	SpaceAfter=No
#
# 6	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Генерал-лейтенант Евгений Абрашин назначен глав...
#
# 1	Генерал	ГЕНЕРАЛ	ADV	AFX	_	6	advmod	_	SpaceAfter=No
#
# 2	-	-	PUNCT	-	_	1	goeswith	_	SpaceAfter=No
#
# 3	лейтенант	ЛЕЙТЕНАНТ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	goeswith	_	_
#
# 4	Евгений	ЕВГЕНИЙ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	nsubj:pass	_	_
#
# 5	Абрашин	Абрашин	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	flat	_	_
#
# 6	назначен	НАЗНАЧИТЬ	VERB	VBNH	Animacy=Anim|Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	0	root	_	_
#
# 7	глав	глав	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	nsubj:pass	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Приставка и.о. носит скорее всего временный хар...
#
# 1	Приставка	ПРИСТАВКА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	6	nsubj	_	_
#
# 2	и	И	CCONJ	CC	_	6	cc	_	SpaceAfter=No
#
# 3	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 4	о	О	ADP	IN	_	5	case	_	SpaceAfter=No
#
# 5	.	.	PUNCT	.	_	6	punct	_	_
#
# 6	носит	НОСИТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 7	скорее	СКОРЕЕ	ADV	RBR	Degree=Cmp	8	advmod	_	_
#
# 8	всего	ВЕСЬ	ADV	RB	_	9	advmod	_	_
#
# 9	временный	временный	VERB	VBNL	Animacy=Inan|Aspect=Perf|Case=Acc|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	10	acl	_	_
#
# 10	хар	хар	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	6	obj	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	10	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Предшественника Абрашина генерал-майора Сергея ...
#
# 1	Предшественника	Предшественника	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	Абрашина	Абрашина	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	flat	_	_
#
# 3	генерал	ГЕНЕРАЛ	ADV	AFX	_	1	nmod	_	SpaceAfter=No
#
# 4	-	-	PUNCT	-	_	3	goeswith	_	SpaceAfter=No
#
# 5	майора	МАЙОР	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	3	goeswith	_	_
#
# 6	Сергея	СЕРГЕЙ	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	3	nmod	_	_
#
# 7	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Абрашин уже третий комендант республики с начал...
#
# 1	Абрашин	Абрашин	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	nsubj	_	_
#
# 2	уже	УЖЕ	ADV	RB	_	4	discourse	_	_
#
# 3	третий	ТРЕТИЙ	ADJ	ORD	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	4	amod	_	_
#
# 4	комендант	НАкомендТ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	7	nsubj	_	_
#
# 5	республики	РЕСПУБЛИКА	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	4	nmod	_	_
#
# 6	с	С	ADP	IN	_	7	case	_	_
#
# 7	начал	НАЧАТЬ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Предыдущий пост генерала Абрашина-- заместитель...
#
# 1	Предыдущий	Предыдущий	VERB	VBNL	Animacy=Inan|Aspect=Imp|Case=Nom|Gender=Masc|Number=Sing|Tense=Pres|VerbForm=Part|Voice=Act	2	acl	_	_
#
# 2	пост	ПОСТ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 3	генерала	ГЕНЕРАЛ	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	2	nmod	_	_
#
# 4	Абрашина	Абрашина	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	3	appos	_	SpaceAfter=No
#
# 5	-	-	PUNCT	-	_	4	goeswith	_	SpaceAfter=No
#
# 6	-	-	PUNCT	-	_	4	goeswith	_	_
#
# 7	заместитель	ЗАМЕСТИТЕЛЬ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	goeswith	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Абрашину 50 лет, он бывший армейский офицер, ка...
#
# 1	Абрашину	Абрашину	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	0	root	_	_
#
# 2	50	50	NUM	CD	Case=Acc|NumType=Card	3	nummod:gov	_	_
#
# 3	лет	ГОД	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	1	advmod	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	1	punct	_	_
#
# 5	он	ОН	PRON	PRP	Case=Nom|Gender=Masc|Number=Sing|Person=3	8	nsubj	_	_
#
# 6	бывший	БЫВШИЙ	ADJ	JJL	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	8	amod	_	_
#
# 7	армейский	армейский	ADJ	JJL	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	8	amod	_	_
#
# 8	офицер	ОФИЦЕР	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	parataxis	_	SpaceAfter=No
#
# 9	,	,	PUNCT	,	_	10	punct	_	_
#
# 10	ка	ка	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	8	conj	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Шесть лет назад появился на Кавказе уже в качес...
#
# 1	Шесть	ШЕСТЬ	NUM	CD	Case=Acc|NumType=Card	2	nummod:gov	_	_
#
# 2	лет	ГОД	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur	4	obl	_	_
#
# 3	назад	НАЗАД	ADV	RB	_	4	advmod	_	_
#
# 4	появился	ПОЯВИТЬСЯ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 5	на	НА	ADP	IN	_	6	case	_	_
#
# 6	Кавказе	КАВКАЗ	PROPN	NNP	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	4	obl	_	_
#
# 7	уже	УЖЕ	ADV	UH	_	9	discourse	_	_
#
# 8	в	В	ADP	IN	_	9	case	_	_
#
# 9	качес	качес	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	4	obl	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Отработал три командировки в Чечне, одно время ...
#
# 1	Отработал	ОтРАБОТАТЬ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 2	три	ТРИ	NUM	CD	Animacy=Inan|Case=Acc|NumType=Card	3	nummod:gov	_	_
#
# 3	командировки	командировки	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	1	obj	_	_
#
# 4	в	В	ADP	IN	_	5	case	_	_
#
# 5	Чечне	Чечне	PROPN	NNP	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	3	nmod	_	SpaceAfter=No
#
# 6	,	,	PUNCT	,	_	8	punct	_	_
#
# 7	одно	ОДИН	NUM	CD	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing|NumType=Card	8	nummod	_	_
#
# 8	время	ВРЕМЯ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	1	obj	_	_
#
# 9	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Абрашин-- креатура генерал-полковника Баранова,...
#
# 1	Абрашин	Абрашин	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	SpaceAfter=No
#
# 2	-	-	PUNCT	-	_	1	goeswith	_	SpaceAfter=No
#
# 3	-	-	PUNCT	-	_	1	goeswith	_	_
#
# 4	креатура	креаТУР	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	1	goeswith	_	_
#
# 5	генерал	ГЕНЕРАЛ	ADV	AFX	_	0	root	_	SpaceAfter=No
#
# 6	-	-	PUNCT	-	_	5	goeswith	_	SpaceAfter=No
#
# 7	полковника	ПОЛКОВНИК	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	5	goeswith	_	_
#
# 8	Баранова	Баранова	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	5	nmod	_	SpaceAfter=No
#
# 9	,	,	PUNCT	,	_	5	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Валерий Баранов принимает активное участие в на...
#
# 1	Валерий	ВАЛЕРИЙ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	3	nsubj	_	_
#
# 2	Баранов	Баранов	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	flat	_	_
#
# 3	принимает	пРИНИМАТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 4	активное	АКТИВНЫЙ	ADJ	JJL	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	5	amod	_	_
#
# 5	участие	УЧАСТИЕ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	3	obj	_	_
#
# 6	в	В	ADP	IN	_	7	case	_	_
#
# 7	на	НА	ADP	IN	_	8	case	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В августе 2001 года Баранов отстранил от должно...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	августе	АВГУСТ	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	6	obl	_	_
#
# 3	2001	2001	ADJ	ORD	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	4	amod	_	_
#
# 4	года	ГОД	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	2	nmod	_	_
#
# 5	Баранов	Баранов	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	nsubj	_	_
#
# 6	отстранил	отстранил	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 7	от	ОТ	ADP	IN	_	8	case	_	_
#
# 8	должно	ДОЛЖЕН	ADJ	JJH	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing|Variant=Short	6	obl	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = По неофициальной информации, Бабичев пострадал ...
#
# 1	По	ПО	ADP	IN	_	3	case	_	_
#
# 2	неофициальной	НЕОФИЦИАЛЬНЫЙ	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	amod	_	_
#
# 3	информации	ИНФОРМАЦИЯ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	6	obl	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	3	punct	_	_
#
# 5	Бабичев	Бабичев	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	nsubj	_	_
#
# 6	пострадал	пострадал	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 7	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Место Бабичева занял генерал-майор Кизюн, котор...
#
# 1	Место	МЕСТО	ADP	IN	_	2	case	_	_
#
# 2	Бабичева	Бабичева	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	3	obl	_	_
#
# 3	занял	ЗАНЯТЬ	VERB	VBC	Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	0	root	_	_
#
# 4	генерал	ГЕНЕРАЛ	ADV	AFX	_	3	nsubj	_	SpaceAfter=No
#
# 5	-	-	PUNCT	-	_	4	goeswith	_	SpaceAfter=No
#
# 6	майор	МАЙОР	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	goeswith	_	_
#
# 7	Кизюн	Кизюн	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	appos	_	SpaceAfter=No
#
# 8	,	,	PUNCT	,	_	4	punct	_	_
#
# 9	котор	котор	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	4	appos	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Отставка Кизюна была неизбежной.
#
# 1	Отставка	ОтсТАВКА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	4	nsubj	_	_
#
# 2	Кизюна	Кизюна	PROPN	NNP	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	1	appos	_	_
#
# 3	была	БЫТЬ	AUX	VBC	Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin	4	cop	_	_
#
# 4	неизбежной	неизбежной	ADJ	JJL	Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing	0	root	_	SpaceAfter=No
#
# 5	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В Чеченской Республике с декабря прошлого года ...
#
# 1	В	В	ADP	IN	_	3	case	_	_
#
# 2	Чеченской	ЧЕЧЕНСКИЙ	ADJ	JJL	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	3	amod	_	_
#
# 3	Республике	РЕСПУБЛИКА	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	0	root	_	_
#
# 4	с	С	ADP	IN	_	5	case	_	_
#
# 5	декабря	ДЕКАБРЬ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	3	nmod	_	_
#
# 6	прошлого	ПРОШЛЫЙ	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	7	amod	_	_
#
# 7	года	ГОД	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	5	nmod	_	_
#
# 8	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Части Минобороны освобождают комендатуры, вмест...
#
# 1	Части	ЧАСТЬ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur	3	nsubj	_	_
#
# 2	Минобороны	МинОБОРОНА	PROPN	NNP	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	1	nmod	_	_
#
# 3	освобождают	освобождают	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 4	комендатуры	комендатуры	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Plur	3	obj	_	SpaceAfter=No
#
# 5	,	,	PUNCT	,	_	6	punct	_	_
#
# 6	вмест	вМЕСТО	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	4	conj	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = ВВ расположились уже в 15 населенных пунктах ра...
#
# 1	ВВ	В	ADP	IN	_	2	case	_	_
#
# 2	расположились	расположились	VERB	VBC	Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 3	уже	УЖЕ	ADV	UH	_	2	advmod	_	_
#
# 4	в	В	ADP	IN	_	7	case	_	_
#
# 5	15	15	NUM	CD	Case=Loc|NumType=Card	7	nummod	_	_
#
# 6	населенных	населенных	ADJ	JJL	Animacy=Inan|Case=Loc|Number=Plur	7	amod	_	_
#
# 7	пунктах	пунктах	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Masc|Number=Plur	2	obl	_	_
#
# 8	ра	ра	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	7	nmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Войска Минобороны уходят в горную часть, выстра...
#
# 1	Войска	ВОЙСКО	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	3	nsubj	_	_
#
# 2	Минобороны	МинОБОРОНА	PROPN	NNP	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	1	nmod	_	_
#
# 3	уходят	уходят	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 4	в	В	ADP	IN	_	6	case	_	_
#
# 5	горную	горную	ADJ	JJL	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	6	amod	_	_
#
# 6	часть	ЧАСТЬ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	3	obl	_	SpaceAfter=No
#
# 7	,	,	PUNCT	,	_	8	punct	_	_
#
# 8	выстра	выстра	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	6	nmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Формально главные функции по наведению порядка ...
#
# 1	Формально	ФОРМАЛЬНО	ADV	RB	_	3	advmod	_	_
#
# 2	главные	главные	ADJ	JJL	Animacy=Inan|Case=Nom|Number=Plur	3	amod	_	_
#
# 3	функции	ФУНКЦИЯ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur	0	root	_	_
#
# 4	по	ПО	ADP	IN	_	5	case	_	_
#
# 5	наведению	наведению	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing	3	nmod	_	_
#
# 6	порядка	ПОРЯДОК	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	5	nmod	_	_
#
# 7	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Военные комендатуры уже вовсю занимаются полити...
#
# 1	Военные	ВОЕННЫЙ	ADJ	JJL	Animacy=Inan|Case=Nom|Number=Plur	2	amod	_	_
#
# 2	комендатуры	комендатуры	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	5	nsubj	_	_
#
# 3	уже	УЖЕ	ADV	RB	_	5	advmod	_	_
#
# 4	вовсю	воВЕСЬ	DET	DT	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	5	obj	_	_
#
# 5	занимаются	ЗАНИМАТЬСЯ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 6	полити	полИТИ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	5	obj	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = По информации пресс-службы ВВ МВД РФ, они«актив...
#
# 1	По	ПО	ADP	IN	_	2	case	_	_
#
# 2	информации	ИНФОРМАЦИЯ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	0	root	_	_
#
# 3	пресс	ПРЕСС	ADV	AFX	_	6	nmod	_	SpaceAfter=No
#
# 4	-	-	PUNCT	-	_	3	goeswith	_	SpaceAfter=No
#
# 5	службы	СЛУЖБА	SCONJ	IN	_	3	goeswith	_	_
#
# 6	ВВ	В	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	2	appos	_	_
#
# 7	МВД	МВД	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	flat	_	_
#
# 8	РФ	РФ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	7	flat	_	SpaceAfter=No
#
# 9	,	,	PUNCT	,	_	2	punct	_	_
#
# 10	они	ОНИ	PRON	PRP	Case=Nom|Number=Plur|Person=3	12	nsubj	_	SpaceAfter=No
#
# 11	«	«	PUNCT	,	_	12	punct	_	SpaceAfter=No
#
# 12	актив	актив	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	2	appos	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	12	punct	_	SpaceAfter=No
#
# 14	.	.	PUNCT	.	_	12	punct	_	SpaceAfter=No
#
# 15	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Проводят совещания со старейшинами и органами м...
#
# 1	Проводят	ПРОВОДИТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 2	совещания	СОВЕЩАНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur	1	nsubj	_	_
#
# 3	со	СО	ADP	IN	_	4	case	_	_
#
# 4	старейшинами	АНстарейшиМИ	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Fem|Number=Plur	2	nmod	_	_
#
# 5	и	И	CCONJ	CC	_	6	cc	_	_
#
# 6	органами	ОРГАН	NOUN	NN	Animacy=Anim|Case=Ins|Gender=Masc|Number=Plur	4	conj	_	_
#
# 7	м	М	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	6	nmod	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Назначение главным военным комендантом Чечни ми...
#
# 1	Назначение	НАЗНАЧЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	4	nsubj	_	_
#
# 2	главным	ГЛАВНЫЙ	ADJ	JJL	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	4	amod	_	_
#
# 3	военным	ВОЕННЫЙ	ADJ	JJL	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	4	amod	_	_
#
# 4	комендантом	КОМЕНДАНТ	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	0	root	_	_
#
# 5	Чечни	Чечни	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	4	nmod	_	_
#
# 6	ми	МЬ	NUM	CD	Case=Gen|NumType=Card	5	nummod	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Однако говорить о том, что войскам МО отводится...
#
# 1	Однако	ОДНАКО	CCONJ	CC	_	2	cc:preconj	_	_
#
# 2	говорить	ГОВОРИТЬ	VERB	VB	Aspect=Imp|VerbForm=Inf	0	root	_	_
#
# 3	о	О	ADP	IN	_	4	case	_	_
#
# 4	том	ТО	PRON	DT	Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing	2	obl	_	SpaceAfter=No
#
# 5	,	,	PUNCT	,	_	9	punct	_	_
#
# 6	что	ЧТО	SCONJ	IN	_	9	mark	_	_
#
# 7	войскам	ВОЙСКО	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Neut|Number=Plur	9	iobj	_	_
#
# 8	МО	МО	PROPN	NNP	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	9	nsubj	_	_
#
# 9	отводится	отводится	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid	4	acl:relcl	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В понедельник начальник Генштаба Вооруженных си...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	понедельник	понедельник	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 3	начальник	НАЧАЛЬНИК	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	2	appos	_	_
#
# 4	Генштаба	ГенШТАБ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	3	nmod	_	_
#
# 5	Вооруженных	ВООРУЖЕННЫЙ	ADJ	JJL	Animacy=Inan|Case=Gen|Number=Plur	6	amod	_	_
#
# 6	си	си	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	4	nmod	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = По неофициальной информации, во время поездки б...
#
# 1	По	ПО	ADP	IN	_	3	case	_	_
#
# 2	неофициальной	НЕОФИЦИАЛЬНЫЙ	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	amod	_	_
#
# 3	информации	ИНФОРМАЦИЯ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	0	root	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	3	punct	_	_
#
# 5	во	ВО	ADP	IN	_	6	case	_	_
#
# 6	время	ВРЕМЯ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	3	nmod	_	_
#
# 7	поездки	ПОЕЗДКА	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	6	nmod	_	_
#
# 8	б	Б	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur	7	nmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Виноградов Михаил.
#
# 1	Виноградов	ВИНОГРАДОВ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	Михаил	МИХАИЛ	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	flat	_	SpaceAfter=No
#
# 3	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В борьбе за чистое небо.
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	борьбе	БОРЬБА	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	0	root	_	_
#
# 3	за	ЗА	ADP	IN	_	5	case	_	_
#
# 4	чистое	чистое	ADJ	JJL	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	5	amod	_	_
#
# 5	небо	НЕБО	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	2	nmod	_	SpaceAfter=No
#
# 6	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Губернаторы хотят охранять природу
#
# 1	Губернаторы	Губернаторы	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	2	nsubj	_	_
#
# 2	хотят	хотят	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 3	охранять	охранять	VERB	VB	Aspect=Perf|VerbForm=Inf	2	xcomp	_	_
#
# 4	природу	приРОД	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	3	obj	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В пятницу на Старой площади состоялось завершаю...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	пятницу	ПЯТНИЦА	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	6	obl	_	_
#
# 3	на	НА	ADP	IN	_	5	case	_	_
#
# 4	Старой	СТАРЫЙ	ADJ	ORD	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	5	amod	_	_
#
# 5	площади	ПЛОЩАДЬ	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	2	nmod	_	_
#
# 6	состоялось	СОСТОЯТЬСЯ	VERB	VBC	Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 7	завершаю	завершаю	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	6	obj	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	6	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Специалисты в целом удовлетворились подготовлен...
#
# 1	Специалисты	СПЕЦИАЛИСТ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	4	nsubj	_	_
#
# 2	в	В	ADP	IN	_	3	case	_	_
#
# 3	целом	ЦЕЛОЕ	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing	4	obl	_	_
#
# 4	удовлетворились	удовлетворились	VERB	VBC	Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 5	подготовлен	подготовлен	VERB	VBNH	Animacy=Inan|Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|Variant=Short|VerbForm=Part|Voice=Pass	4	xcomp	_	SpaceAfter=No
#
# 6	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Госсовет-- структура странная: в Конституции о ...
#
# 1	Госсовет	ГосСОВЕТ	PROPN	NNP	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	SpaceAfter=No
#
# 2	-	-	PUNCT	-	_	1	goeswith	_	SpaceAfter=No
#
# 3	-	-	PUNCT	-	_	1	goeswith	_	_
#
# 4	структура	СТРУКТУРА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	1	goeswith	_	_
#
# 5	странная	странная	ADJ	JJL	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	0	root	_	SpaceAfter=No
#
# 6	:	:	PUNCT	:	_	5	punct	_	_
#
# 7	в	В	ADP	IN	_	8	case	_	_
#
# 8	Конституции	КОНСТИТУЦИЯ	PROPN	NNP	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	5	nmod	_	_
#
# 9	о	О	ADP	IN	_	10	case	_	_
#
# 10	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Да и заседания ее рабочих групп ничуть не напом...
#
# 1	Да	ДА	CCONJ	CC	_	3	cc	_	_
#
# 2	и	И	PART	UH	_	3	discourse	_	_
#
# 3	заседания	ЗАСЕДАНИЕ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	0	root	_	_
#
# 4	ее	ЕЕ	DET	PRP$	Person=3	6	det	_	_
#
# 5	рабочих	РАБОЧИЙ	ADJ	JJL	Animacy=Inan|Case=Gen|Number=Plur	6	amod	_	_
#
# 6	групп	ГРУППА	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	3	nmod	_	_
#
# 7	ничуть	ниЧУТЬ	VERB	VB	Aspect=Perf|VerbForm=Inf	3	acl	_	_
#
# 8	не	НЕ	PART	NEG	Polarity=Neg	9	advmod	_	_
#
# 9	напом	напом	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	7	iobj	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Выступление докладчика сменяется общим гвалтом,...
#
# 1	Выступление	ВЫСТУПЛЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	3	nsubj	_	_
#
# 2	докладчика	докладчика	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	1	nmod	_	_
#
# 3	сменяется	сменяется	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 4	общим	ОБЩИЙ	ADJ	JJL	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	5	amod	_	_
#
# 5	гвалтом	гвалтом	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing	3	iobj	_	SpaceAfter=No
#
# 6	,	,	PUNCT	,	_	3	punct	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = А обсуждать и решать проблемы надо--«президент ...
#
# 1	А	А	CCONJ	CC	_	10	discourse	_	_
#
# 2	обсуждать	обсуждать	VERB	VB	Aspect=Imp|VerbForm=Inf	10	xcomp	_	_
#
# 3	и	И	CCONJ	CC	_	4	cc	_	_
#
# 4	решать	РЕШАТЬ	VERB	VB	Aspect=Imp|VerbForm=Inf	2	conj	_	_
#
# 5	проблемы	ПРОБЛЕМА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur	10	nsubj	_	_
#
# 6	надо	НАДО	ADV	AFX	_	10	amod	_	SpaceAfter=No
#
# 7	-	-	PUNCT	-	_	6	goeswith	_	SpaceAfter=No
#
# 8	-	-	PUNCT	-	_	6	goeswith	_	SpaceAfter=No
#
# 9	«	«	PUNCT	,	_	6	goeswith	_	SpaceAfter=No
#
# 10	президент	ПРЕЗИДЕНТ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	0	root	_	_
#
# 11	.	.	PUNCT	.	_	10	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	10	punct	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	10	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В пятницу состоялось четвертое(и последнее) зас...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	пятницу	ПЯТНИЦА	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	3	obl	_	_
#
# 3	состоялось	СОСТОЯТЬСЯ	VERB	VBC	Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 4	четвертое	четверТОТ	ADJ	JJL	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	3	obj	_	SpaceAfter=No
#
# 5	(	(	PUNCT	(	_	7	punct	_	SpaceAfter=No
#
# 6	и	И	CCONJ	CC	_	7	cc	_	_
#
# 7	последнее	ПОСЛЕДНИЙ	ADV	RBR	Degree=Cmp	9	advmod	_	SpaceAfter=No
#
# 8	)	)	PUNCT	)	_	7	punct	_	_
#
# 9	зас	зас	ADV	RB	_	10	advmod	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В группу вошли представители федеральных минист...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	группу	ГРУППА	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing	3	obl	_	_
#
# ...
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Часть из них может стать поправками в действующ...
#
# 1	Часть	ЧАСТЬ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	4	nsubj	_	_
#
# 2	из	ИЗ	ADP	IN	_	3	case	_	_
#
# 3	них	ОНИ	PRON	PRP	Case=Gen|Number=Plur|Person=3	1	nmod	_	_
#
# 4	может	МОЧЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 5	стать	СТАТЬ	AUX	VB	Aspect=Perf|VerbForm=Inf	6	cop	_	_
#
# 6	поправками	поправками	NOUN	NN	Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur	4	xcomp	_	_
#
# 7	в	В	ADP	IN	_	8	case	_	_
#
# 8	действующ	действующ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	6	nmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	4	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Например, проблема экологического образования--...
#
# 1	Например	НАПРИМЕР	ADV	RB	_	0	root	_	SpaceAfter=No
#
# 2	,	,	PUNCT	,	_	1	punct	_	_
#
# 3	проблема	ПРОБЛЕМА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	1	nsubj	_	_
#
# 4	экологического	экологического	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	5	amod	_	_
#
# 5	образования	ОБРАЗОВАНИЕ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	3	nmod	_	SpaceAfter=No
#
# 6	-	-	PUNCT	-	_	5	goeswith	_	SpaceAfter=No
#
# 7	-	-	PUNCT	-	_	5	goeswith	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Волошина Виктория.
#
# 1	Волошина	Волошина	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	0	root	_	_
#
# 2	Виктория	Виктория	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	1	flat	_	SpaceAfter=No
#
# 3	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Мигранты, на выход.
#
# 1	Мигранты	Мигранты	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	0	root	_	SpaceAfter=No
#
# 2	,	,	PUNCT	,	_	1	punct	_	_
#
# 3	на	НА	ADP	IN	_	4	case	_	_
#
# 4	выход	ВЫХОД	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	1	nmod	_	SpaceAfter=No
#
# 5	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Приключения иностранцев в России только начинаются
#
# 1	Приключения	Приключения	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Plur	6	nsubj	_	_
#
# 2	иностранцев	иностранцев	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur	1	nmod	_	_
#
# 3	в	В	ADP	IN	_	4	case	_	_
#
# 4	России	РОССИЯ	PROPN	NNP	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	1	nmod	_	_
#
# 5	только	ТОЛЬКО	PART	RB	_	6	discourse	_	_
#
# 6	начинаются	НАЧИНАТЬСЯ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid	0	root	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В четверг управление по делам миграции ГУВД Мос...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	четверг	четверг	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	3	nmod	_	_
#
# 3	управление	УПРАВЛЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	0	root	_	_
#
# 4	по	ПО	ADP	IN	_	5	case	_	_
#
# 5	делам	ДЕЛО	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Neut|Number=Plur	3	nmod	_	_
#
# 6	миграции	МИГРАЦИЯ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	5	nmod	_	_
#
# 7	ГУВД	ГУВД	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	3	nsubj	_	_
#
# 8	Мос	МОС	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	7	flat	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Это управление одно из первых, организуемых сег...
#
# 1	Это	ЭТОТ	DET	DT	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	2	det	_	_
#
# 2	управление	уПРАВЛЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	0	root	_	_
#
# 3	одно	ОДИН	NUM	CD	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing|NumType=Card	2	nmod	_	_
#
# 4	из	ИЗ	ADP	IN	_	8	case	_	_
#
# 5	первых	ПЕРВЫЙ	ADJ	ORD	Animacy=Anim|Case=Gen|Number=Plur	8	amod	_	SpaceAfter=No
#
# 6	,	,	PUNCT	,	_	7	punct	_	_
#
# 7	организуемых	организуемых	ADJ	JJL	Animacy=Inan|Case=Gen|Number=Plur	8	amod	_	_
#
# 8	сег	сег	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	3	nmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Согласно указу президента России отныне иностра...
#
# 1	Согласно	СОГЛАСНО	ADP	IN	_	2	case	_	_
#
# 2	указу	указу	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing	0	root	_	_
#
# 3	президента	ПРЕЗИДЕНТ	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	2	nmod	_	_
#
# 4	России	РОССИЯ	PROPN	NNP	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	nmod	_	_
#
# 5	отныне	отНЫНЕ	ADV	RB	_	6	advmod	_	_
#
# 6	иностра	иностра	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	3	nmod	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	2	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Цель новой службы, по словам главы управления п...
#
# 1	Цель	ЦЕЛЬ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	0	root	_	_
#
# 2	новой	НОВЫЙ	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	amod	_	_
#
# 3	службы	СЛУЖБА	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	1	nmod	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	6	punct	_	_
#
# 5	по	ПО	ADP	IN	_	6	case	_	_
#
# 6	словам	СЛОВО	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Neut|Number=Plur	1	nmod	_	_
#
# 7	главы	ГЛАВА	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Fem|Number=Sing	6	nmod	_	_
#
# 8	управления	УПРАВЛЕНИЕ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing	7	nmod	_	_
#
# 9	п	П	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	8	nmod	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	8	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Новое управление разместилось в Москве на Пятни...
#
# 1	Новое	НОВЫЙ	ADJ	JJL	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	2	amod	_	_
#
# 2	управление	УПРАВЛЕНИЕ	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing	3	nsubj	_	_
#
# 3	разместилось	разместилось	VERB	VBC	Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 4	в	В	ADP	IN	_	5	case	_	_
#
# 5	Москве	МОСКВА	PROPN	NNP	Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing	3	obl	_	_
#
# 6	на	НА	ADP	IN	_	7	case	_	_
#
# 7	Пятни	Пятни	PROPN	NNP	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	3	obl	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	3	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	3	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = На металлической двери при входе пока нет никак...
#
# 1	На	НА	ADP	IN	_	3	case	_	_
#
# 2	металлической	металлической	ADJ	JJL	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	3	amod	_	_
#
# 3	двери	ДВЕРЬ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	7	obl	_	_
#
# 4	при	ПРИ	ADP	IN	_	5	case	_	_
#
# 5	входе	ВХОД	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	7	obl	_	_
#
# 6	пока	ПОКА	ADV	RB	_	7	advmod	_	_
#
# 7	нет	НЕТ	VERB	VBC	Aspect=Imp|Tense=Pres	0	root	_	_
#
# 8	никак	НИКАК	ADV	RB	_	9	advmod	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = В кабинете подполковник и его зам изучают«Росси...
#
# 1	В	В	ADP	IN	_	2	case	_	_
#
# 2	кабинете	кабинете	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	7	obl	_	_
#
# 3	подполковник	подПОЛКОВНИК	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	7	nsubj	_	_
#
# 4	и	И	CCONJ	CC	_	6	cc	_	_
#
# 5	его	ЕГО	DET	PRP$	Person=3	6	det	_	_
#
# 6	зам	зам	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Fem|Number=Plur	3	conj	_	_
#
# 7	изучают	изучают	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 8	«	«	PUNCT	,	_	9	punct	_	SpaceAfter=No
#
# 9	Росси	Росси	PROPN	NNP	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	7	appos	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Через три месяца после публикации закон вступит...
#
# 1	Через	ЧЕРЕЗ	ADP	IN	_	3	case	_	_
#
# 2	три	ТРИ	NUM	CD	Animacy=Inan|Case=Acc|NumType=Card	3	nummod:gov	_	_
#
# 3	месяца	МЕСЯЦ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing	7	obl	_	_
#
# 4	после	ПОСЛЕ	ADP	IN	_	5	case	_	_
#
# 5	публикации	ПУБЛИКАЦИЯ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing	7	obl	_	_
#
# 6	закон	ЗАКОН	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing	7	nsubj	_	_
#
# 7	вступит	ВСТУПИТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	7	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = За это время, говорит подполковник, при управле...
#
# 1	За	ЗА	ADP	IN	_	3	case	_	_
#
# 2	это	ЭТОТ	DET	DT	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	3	det	_	_
#
# 3	время	ВРЕМЯ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	5	obl	_	SpaceAfter=No
#
# 4	,	,	PUNCT	,	_	3	punct	_	_
#
# 5	говорит	ГОВОРИТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 6	подполковник	подПОЛКОВНИК	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	5	nsubj	_	SpaceAfter=No
#
# 7	,	,	PUNCT	,	_	8	punct	_	_
#
# 8	при	ПРИ	ADP	IN	_	9	case	_	_
#
# 9	управле	управле	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing	5	obl	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = -- По новому закону,-- Сперкач отмечает абзац в...
#
# 1	-	-	PUNCT	-	_	10	nsubj	_	SpaceAfter=No
#
# 2	-	-	PUNCT	-	_	1	goeswith	_	_
#
# 3	По	ПО	ADP	AFX	_	1	goeswith	_	_
#
# 4	новому	НОВЫЙ	ADJ	JJL	Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing	1	amod	_	_
#
# 5	закону	ЗАКОН	NOUN	NN	Animacy=Inan|Case=Dat|Gender=Masc|Number=Sing	1	goeswith	_	SpaceAfter=No
#
# 6	,	,	PUNCT	,	_	1	punct	_	SpaceAfter=No
#
# 7	-	-	PUNCT	-	_	1	goeswith	_	SpaceAfter=No
#
# 8	-	-	PUNCT	-	_	1	goeswith	_	_
#
# 9	Сперкач	Сперкач	PROPN	NNP	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	1	goeswith	_	_
#
# 10	отмечает	ОТМЕЧАТЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 11	абзац	абзац	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	10	obj	_	_
#
# 12	в	В	ADP	IN	_	13	case	_	SpaceAfter=No
#
# 13	.	.	PUNCT	.	_	10	punct	_	SpaceAfter=No
#
# 14	.	.	PUNCT	.	_	10	punct	_	SpaceAfter=No
#
# 15	.	.	PUNCT	.	_	10	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Понятно, что не все поспешат сделать это добров...
#
# 1	Понятно	Понятно	VERB	PRED	Degree=Pos	0	root	_	SpaceAfter=No
#
# 2	,	,	PUNCT	,	_	6	punct	_	_
#
# 3	что	ЧТО	SCONJ	IN	_	6	mark	_	_
#
# 4	не	НЕ	PART	NEG	Polarity=Neg	5	advmod	_	_
#
# 5	все	ВЕСЬ	DET	DT	Animacy=Inan|Case=Nom|Number=Plur	6	det	_	_
#
# 6	поспешат	поспешат	ADJ	JJH	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing|Variant=Short	1	ccomp	_	_
#
# 7	сделать	сДЕЛАТЬ	VERB	VB	Aspect=Perf|VerbForm=Inf	6	xcomp	_	_
#
# 8	это	ЭТОТ	DET	DT	Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing	9	det	_	_
#
# 9	добров	добров	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	7	obj	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Придется проводить внезапные проверки.
#
# 1	Придется	ПРИЙТИСЬ	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Mid	0	root	_	_
#
# 2	проводить	ПРОВОДИТЬ	VERB	VB	Aspect=Imp|VerbForm=Inf	1	xcomp	_	_
#
# 3	внезапные	внезапные	ADJ	JJL	Animacy=Inan|Case=Acc|Number=Plur	4	amod	_	_
#
# 4	проверки	ПРОВЕРКА	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Fem|Number=Plur	2	obj	_	SpaceAfter=No
#
# 5	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Правда, у нас в управлении только два человека ...
#
# 1	Правда	ПРАВДА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	9	nsubj	_	SpaceAfter=No
#
# 2	,	,	PUNCT	,	_	1	punct	_	_
#
# 3	у	У	ADP	IN	_	4	case	_	_
#
# 4	нас	МЫ	PRON	PRP	Case=Acc|Number=Plur|Person=1	2	obl	_	_
#
# 5	в	В	ADP	IN	_	6	case	_	_
#
# 6	управлении	управлении	NOUN	NN	Animacy=Inan|Case=Loc|Gender=Neut|Number=Sing	1	nmod	_	_
#
# 7	только	ТОЛЬКО	PART	RB	_	8	discourse	_	_
#
# 8	два	ДВА	NUM	CD	Animacy=Anim|Case=Nom|Gender=Masc|NumType=Card	9	nummod:gov	_	_
#
# 9	человека	ЧЕЛОВЕК	NOUN	NN	Animacy=Anim|Case=Gen|Gender=Masc|Number=Sing	0	root	_	_
#
# 10	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	9	punct	_	SpaceAfter=No
#
# 12	.	.	PUNCT	.	_	9	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Так что рейды мы будем проводить во взаимодейст...
#
# 1	Так	ТАК	ADV	RB	_	5	advmod	_	_
#
# 2	что	ЧТО	SCONJ	IN	_	5	mark	_	_
#
# 3	рейды	рейды	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur	5	nsubj	_	_
#
# 4	мы	МЫ	PRON	PRP	Case=Nom|Number=Plur|Person=1	5	nsubj	_	_
#
# 5	будем	ТОбуд	VERB	VBC	Aspect=Imp|Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	0	root	_	_
#
# 6	проводить	ПРОВОДИТЬ	VERB	VB	Aspect=Imp|VerbForm=Inf	5	xcomp	_	_
#
# 7	во	ВО	ADP	IN	_	8	case	_	_
#
# 8	взаимодейст	взаимодЕЙСТ	NOUN	NN	Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing	6	obl	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	5	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Тем более что нелегальные иммигранты зачастую т...
#
# 1	Тем	ТО	PRON	DT	Animacy=Inan|Case=Ins|Gender=Neut|Number=Sing	0	root	_	_
#
# 2	более	БОЛЕЕ	ADV	RBR	Degree=Cmp	3	advmod	_	_
#
# 3	что	ЧТО	SCONJ	IN	_	5	mark	_	_
#
# 4	нелегальные	нелегальные	ADJ	JJL	Animacy=Anim|Case=Nom|Number=Plur	5	amod	_	_
#
# 5	иммигранты	ИММиГРАНТ	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur	1	nsubj	_	_
#
# 6	зачастую	ЗАЧАСТУЮ	ADV	RB	_	7	advmod	_	_
#
# 7	т	Т	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur	5	nmod	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	5	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	1	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Директора предприятий, использующие труд иностр...
#
# 1	Директора	ДИРЕКТОР	NUM	CD	Case=Gen|Gender=Masc|NumType=Card	2	nummod:gov	_	_
#
# 2	предприятий	ПРЕДПРИЯТИЕ	NOUN	NN	Animacy=Inan|Case=Gen|Gender=Neut|Number=Plur	0	root	_	SpaceAfter=No
#
# 3	,	,	PUNCT	,	_	6	punct	_	_
#
# 4	использующие	использующие	VERB	VBNL	Animacy=Inan|Aspect=Imp|Case=Nom|Number=Plur|Tense=Pres|VerbForm=Part|Voice=Act	6	acl	_	_
#
# 5	труд	ТРУД	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	6	nsubj	_	_
#
# 6	иностр	иностр	NOUN	NN	Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing	2	appos	_	SpaceAfter=No
#
# 7	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 8	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Правда, что делать с нелегалами-гастарбайтерами...
#
# 1	Правда	ПРАВДА	NOUN	NN	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	0	root	_	SpaceAfter=No
#
# 2	,	,	PUNCT	,	_	4	punct	_	_
#
# 3	что	ЧТО	SCONJ	IN	_	4	mark	_	_
#
# 4	делать	ДЕЛАТЬ	VERB	VB	Aspect=Imp|VerbForm=Inf	1	ccomp	_	_
#
# 5	с	С	ADP	IN	_	6	case	_	_
#
# 6	нелегалами	нелегалами	NOUN	NN	Animacy=Anim|Case=Ins|Gender=Masc|Number=Plur	4	obl	_	SpaceAfter=No
#
# 7	-	-	PUNCT	-	_	6	goeswith	_	SpaceAfter=No
#
# 8	гастарбайтерами	гастарбайтерами	NOUN	NN	Animacy=Anim|Case=Ins|Gender=Masc|Number=Plur	6	goeswith	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	6	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	4	punct	_	SpaceAfter=No
#
# 11	.	.	PUNCT	.	_	1	punct	_	SpacesAfter=\n
#
#
#
# # newdoc
#
# # newpar
#
# # sent_id = 1
#
# # text = Довольно трудно юридически доказать, что нищие ...
#
# 1	Довольно	ДОВОЛЬНО	ADV	RB	_	2	advmod	_	_
#
# 2	трудно	ТРУДНО	VERB	PRED	Degree=Pos	0	root	_	_
#
# 3	юридически	юридически	ADV	RB	_	4	advmod	_	_
#
# 4	доказать	доказать	VERB	VB	Aspect=Imp|VerbForm=Inf	2	xcomp	_	SpaceAfter=No
#
# 5	,	,	PUNCT	,	_	7	punct	_	_
#
# 6	что	ЧТО	SCONJ	IN	_	7	mark	_	_
#
# 7	нищие	нищие	ADJ	JJL	Animacy=Anim|Case=Nom|Number=Plur	4	ccomp	_	_
#
# 8	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 9	.	.	PUNCT	.	_	7	punct	_	SpaceAfter=No
#
# 10	.	.	PUNCT	.	_	2	punct	_	SpacesAfter=\n

# %%
syntax_properties
# Out:
# {'в': {'case': 27, 'appos|flat|nmod': 1}}

# %%
len(line.split('\t'))
# Out:
# 10

# %%
from collections import Counter

# %%
da = open('rnc_raw/rnc_raw0.txt.gz').readlines()

# %%
from ufal.udpipe import Model, Pipeline

# %%
! pip install !wget https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3131/russian-syntagrus-ud-2.5-191206.udpipe?sequence=70&isAlloy
# Out:
# zsh:1: no matches found: https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3131/russian-syntagrus-ud-2.5-191206.udpipe?sequence=70
# zsh:1: command not found: isAlloy

# %%
model = Model.load("russian-syntagrus-ud-2.5-191206.udpipe")

# %%
with open('test.conllu', 'a') as fw:
    for :
        parsed = pipeline.process(l.strip())
        fw.write(parsed)

# %%
pipeline = Pipeline(model, 'generic_tokenizer', '', '', '')
example = "Если бы мне платили каждый раз. Каждый раз, когда я думаю о тебе."
parsed = pipeline.process(da[8].strip())
print(parsed)
# Out:
# # newdoc
# # newpar
# # sent_id = 1
# # text = И вообще,«появилась схема, она работает, решают...
# 1	И	и	CCONJ	_	_	5	cc	_	_
# 2	вообще	вообще	ADV	_	Degree=Pos	5	parataxis	_	SpaceAfter=No
# 3	,	,	PUNCT	_	_	2	punct	_	SpaceAfter=No
# 4	«	«	PUNCT	_	_	2	punct	_	SpaceAfter=No
# 5	появилась	появиться	VERB	_	Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid	0	root	_	_
# 6	схема	схема	NOUN	_	Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing	5	nsubj	_	SpaceAfter=No
# 7	,	,	PUNCT	_	_	9	punct	_	_
# 8	она	она	PRON	_	Case=Nom|Gender=Fem|Number=Sing|Person=3	9	nsubj	_	_
# 9	работает	работать	VERB	_	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	5	conj	_	SpaceAfter=No
# 10	,	,	PUNCT	_	_	11	punct	_	_
# 11	решают	решить	VERB	_	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	5	conj	_	SpaceAfter=No
# 12	.	.	PUNCT	_	_	11	punct	_	SpaceAfter=No
# 13	.	.	PUNCT	_	_	5	punct	_	SpaceAfter=No
# 14	.	.	PUNCT	_	_	5	punct	_	SpacesAfter=\n

# %%
parsed

# %%
for i in tqdm(range(7)):
    with open('rnc_raw%s.txt'%(i), 'w') as fw:
        dfAsString = f.RAW[f.shape[0]//7*i:f.shape[0]//7*(i+1)].to_string(header=False, index=False)
        fw.write(dfAsString)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
for i in range(0, f.shape[0]+1, f.shape[0]//7):
    print(i)
# Out:
# 0
# 3784065
# 7568130
# 11352195
# 15136260
# 18920325
# 22704390
# 26488455

# %%
f.shape[0]
# Out:
# 26488455
